# %%
import requests
from datetime import datetime, timedelta

def harvest_zenodo_records(from_date, to_date=None):
    if not to_date:
        to_date = (from_date + timedelta(days=1)).date()
    if isinstance(from_date, datetime):
        from_date = from_date.date()
    if isinstance(to_date, datetime):
        to_date = to_date.date()
    headers = {"Content-Type": "application/json"}
    params = {
        'size': 500,
        'page': 1,
        'q': 'created:[{from_date} TO {to_date}]'.format(from_date=from_date, to_date=to_date)
    }
    url = 'https://zenodo.org/api/records'
    records = []
    res = requests.get(url, headers=headers, params=params).json()
    records.extend(res['hits']['hits'])
    while 'next' in res['links']:
        res = requests.get(res['links']['next'], headers=headers).json()
        records.extend(res['hits']['hits'])
    return records

resp = harvest_zenodo_records(datetime.now())

def prepare_features(rec):
    return rec['metadata']['description'] + rec['metadata']['title']

from sklearn.externals import joblib
text_clf = joblib.load('2017_06_14_record_spam.pkl')

# %%
test_X = [prepare_features(d) for d in resp]

# %%
y = text_clf.predict(test_X)

# %%
from collections import Counter

# %%
spams = list(r for r, y in zip(resp, y) if y)

# %%
spams[0]
# Out:
# {'conceptdoi': '10.5281/zenodo.808143',
#  'conceptrecid': '808143',
#  'created': '2017-06-14T08:39:51.771905+00:00',
#  'doi': '10.5281/zenodo.808144',
#  'id': 808144,
#  'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.808144.svg',
#   'bucket': 'https://zenodo.org/api/files/8206b8ed-2837-432f-8f7a-a40ccf2739fa',
#   'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.808143.svg',
#   'conceptdoi': 'https://doi.org/10.5281/zenodo.808143',
#   'doi': 'https://doi.org/10.5281/zenodo.808144',
#   'html': 'https://zenodo.org/record/808144',
#   'latest': 'https://zenodo.org/api/records/808144',
#   'latest_html': 'https://zenodo.org/record/808144',
#   'self': 'https://zenodo.org/api/records/808144'},
#  'metadata': {'access_right': 'open',
#   'access_right_category': 'success',
#   'creators': [{'name': 'ADMIN'}],
#   'description': '<p><strong>GBM 380 Global Business</strong></p>\n\n<p><strong>To purchase this material click below link</strong></p>\n\n<p>\xa0</p>\n\n<p><strong>http://www.assignmentcloud.com/GBM-380/GBM-380-Complete-Class-Guide</strong></p>\n\n<p><strong>For more classes visit</strong></p>\n\n<p><strong>www.assignmentcloud.com</strong></p>\n\n<p>\xa0</p>\n\n<p><strong>GBM 380 Global Business</strong></p>\n\n<p>\xa0</p>\n\n<p>\xa0</p>\n\n<p>\xa0</p>\n\n<p>\xa0</p>\n\n<p>\xa0</p>\n\n<p>\xa0</p>\n\n<p>\xa0</p>\n\n<p>\xa0</p>\n\n<p><strong>GBM 380 Week 1 Individual Globalization Paper</strong></p>\n\n<p>\xa0</p>\n\n<p><strong>To purchase this material click below link</strong></p>\n\n<p>\xa0</p>\n\n<p><strong>http://www.assignmentcloud.com/GBM-380/GBM-380-Week-1-Individual-Globalization-Paper</strong></p>\n\n<p><strong>For more classes visit</strong></p>\n\n<p><strong>www.assignmentcloud.com</strong></p>\n\n<p>\xa0</p>\n\n<p><strong>GBM 380 Week 1 Individual Globalization Paper</strong></p>\n\n<p><strong>Write a 1,050-1,750-word paper in which you define globalization, and identify challenges and opportunities associated with globalization. Locate at least two references.</strong></p>\n\n<p><strong>Format your paper consistent with APA guidelines.</strong></p>\n\n<p><strong>Click the Assignment Files tab to submit your assignment.</strong></p>\n\n<p>\xa0</p>\n\n<p>\xa0</p>\n\n<p>\xa0</p>\n\n<p>\xa0</p>\n\n<p>\xa0</p>\n\n<p>\xa0</p>\n\n<p>\xa0</p>\n\n<p>\xa0</p>\n\n<p>\xa0</p>\n\n<p><strong>GBM 380 Week 2 Individual Business Organizations Paper</strong></p>\n\n<p>\xa0</p>\n\n<p><strong>To purchase this material click below link</strong></p>\n\n<p>\xa0</p>\n\n<p><strong>http://www.assignmentcloud.com/GBM-380/GBM-380-Week-2-Individual-Business-Organizations-Paper</strong></p>\n\n<p><strong>For more classes visit</strong></p>\n\n<p><strong>www.assignmentcloud.com</strong></p>\n\n<p>\xa0</p>\n\n<p><strong>GBM 380 Week 2 Individual Business Organizations Paper</strong></p>\n\n<p><strong>Write a 350- to 700-word paper in which you list one example of each of the following categories of business organizations:</strong></p>\n\n<p><strong>•\xa0\xa0 \xa0Domestic</strong></p>\n\n<p><strong>•\xa0\xa0 \xa0International</strong></p>\n\n<p><strong>•\xa0\xa0 \xa0Multinational</strong></p>\n\n<p><strong>•\xa0\xa0 \xa0Regional</strong></p>\n\n<p><strong>•\xa0\xa0 \xa0Global</strong></p>\n\n<p><strong>Explain and justify your selection of the business organizations for each category.</strong></p>\n\n<p><strong>Format your paper consistent with APA guidelines.</strong></p>\n\n<p><strong>Click the Assignment Files tab to submit your assignment.</strong></p>\n\n<p>\xa0</p>\n\n<p>\xa0</p>\n\n<p>\xa0</p>\n\n<p>\xa0</p>\n\n<p>\xa0</p>\n\n<p>\xa0</p>\n\n<p>\xa0</p>\n\n<p>\xa0</p>\n\n<p><strong>GBM 380 Week 2 Learning Team Globalization Trends Paper</strong></p>\n\n<p>\xa0</p>\n\n<p><strong>To purchase this material click below link</strong></p>\n\n<p>\xa0</p>\n\n<p><strong>http://www.assignmentcloud.com/GBM-380/GBM-380-Week-2-Learning-Team-Globalization-Trends-Paper</strong></p>\n\n<p><strong>For more classes visit</strong></p>\n\n<p><strong>www.assignmentcloud.com</strong></p>\n\n<p>\xa0</p>\n\n<p><strong>GBM 380 Week 2 Learning Team Globalization Trends Paper</strong></p>\n\n<p><strong>Write a 1,050- to 1,750-word paper analyzing two globalization trends, such as outsourcing, e-commerce, or global consumption patterns. In your analysis, include the following:</strong></p>\n\n<p><strong>•\xa0\xa0 \xa0Identify the reasons for the trends.</strong></p>\n\n<p><strong>•\xa0\xa0 \xa0Identify non-North American countries affected by these trends.</strong></p>\n\n<p><strong>•\xa0\xa0 \xa0Explain how these countries are affected by these trends.</strong></p>\n\n<p><strong>•\xa0\xa0 \xa0Identify organizations or industries that are facilitating the trends.</strong></p>\n\n<p><strong>Format your paper consistent with APA guidelines.</strong><br>\n<strong><strong ...
#   'doi': '10.5281/zenodo.808144',
#   'keywords': ['gbm 380 new,uop gbm 380 new,uop gbm 380 new complete course,uop gbm 380 new entire course,uop gbm 380 new week 1,uop gbm 380 new week 2,uop gbm 380 new week 3,uop gbm 380 new week 4,uop gbm 380 new week 5,uop gbm 380 new tutorials,gbm 380 new assignments,gbm 380 new help'],
#   'license': {'id': 'CC-BY-4.0'},
#   'publication_date': '2017-06-14',
#   'related_identifiers': [{'identifier': '10.5281/zenodo.808143',
#     'relation': 'isPartOf',
#     'scheme': 'doi'}],
#   'relations': {'version': [{'count': 1,
#      'index': 0,
#      'is_last': True,
#      'last_child': {'pid_type': 'recid', 'pid_value': '808144'},
#      'parent': {'pid_type': 'recid', 'pid_value': '808143'}}]},
#   'resource_type': {'subtype': 'article',
#    'title': 'Journal article',
#    'type': 'publication'},
#   'title': 'GBM 380 Global Business'},
#  'owners': [30894],
#  'revision': 2,
#  'updated': '2017-06-14T13:50:54.336963+00:00'}

# %%
Counter(list(s['owners'][0] for s in spams))
# Out:
# Counter({30532: 10, 30894: 13, 32283: 62, 32735: 16})

# %%
def prepare_features(rec):
    return rec['description'] + rec['title']

from sklearn.externals import joblib
text_clf = joblib.load('2017_06_14_record_spam.pkl')

# %%
len(resp)
# Out:
# 392

# %%
resp[0]
# Out:
# {'conceptdoi': '10.5281/zenodo.807826',
#  'conceptrecid': '807826',
#  'created': '2017-06-14T07:13:55.748781+00:00',
#  'doi': '10.5281/zenodo.807827',
#  'id': 807827,
#  'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807827.svg',
#   'bucket': 'https://zenodo.org/api/files/c12e356e-9d94-46bc-929e-7d42521dbac9',
#   'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807826.svg',
#   'conceptdoi': 'https://doi.org/10.5281/zenodo.807826',
#   'doi': 'https://doi.org/10.5281/zenodo.807827',
#   'html': 'https://zenodo.org/record/807827',
#   'latest': 'https://zenodo.org/api/records/807827',
#   'latest_html': 'https://zenodo.org/record/807827',
#   'self': 'https://zenodo.org/api/records/807827'},
#  'metadata': {'access_right': 'open',
#   'access_right_category': 'success',
#   'communities': [{'id': 'biosyslit'}],
#   'creators': [{'name': 'Doğan, Sibel'},
#    {'name': 'Doğan, Salih'},
#    {'name': 'Erman, Orhan'}],
#   'description': 'FIGURE 4. Stigmaeus communis sp. nov. (Male) A. Dorsal view of idiosoma, B. Ventral view of idiosoma.',
#   'doi': '10.5281/zenodo.807827',
#   'keywords': ['Biodiversity',
#    'Taxonomy',
#    'Animalia',
#    'Arthropoda',
#    'Arachnida',
#    'Prostigmata',
#    'Stigmaeidae',
#    'Stigmaeus'],
#   'license': {'id': 'notspecified'},
#   'publication_date': '2017-12-31',
#   'related_identifiers': [{'identifier': 'http://treatment.plazi.org/id/03F087A3FFE18850FF04AE53FF7F88CA',
#     'relation': 'isCitedBy',
#     'scheme': 'url'},
#    {'identifier': '10.11646/zootaxa.4276.4.1',
#     'relation': 'isPartOf',
#     'scheme': 'doi'},
#    {'identifier': 'urn:lsid:plazi.org:pub:FFC9FFDBFFE08855FF93AC31FFA08B04',
#     'relation': 'isPartOf',
#     'scheme': 'lsid'},
#    {'identifier': 'https://zenodo.org/record/807819',
#     'relation': 'isPartOf',
#     'scheme': 'url'},
#    {'identifier': '10.5281/zenodo.807826',
#     'relation': 'isPartOf',
#     'scheme': 'doi'}],
#   'relations': {'version': [{'count': 1,
#      'index': 0,
#      'is_last': True,
#      'last_child': {'pid_type': 'recid', 'pid_value': '807827'},
#      'parent': {'pid_type': 'recid', 'pid_value': '807826'}}]},
#   'resource_type': {'subtype': 'figure', 'title': 'Figure', 'type': 'image'},
#   'title': 'FIGURE 4 in Description of five new species of the genus Stigmaeus Koch (Acari: Raphignathoidea: Stigmaeidae) from Turkey'},
#  'owners': [1161],
#  'revision': 1,
#  'updated': '2017-06-14T07:13:55.940478+00:00'}

# %%
resp.json()['hits']['hits']
# Out:
# [{'conceptdoi': '10.5281/zenodo.807826',
#   'conceptrecid': '807826',
#   'created': '2017-06-14T07:13:55.748781+00:00',
#   'doi': '10.5281/zenodo.807827',
#   'id': 807827,
#   'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807827.svg',
#    'bucket': 'https://zenodo.org/api/files/c12e356e-9d94-46bc-929e-7d42521dbac9',
#    'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807826.svg',
#    'conceptdoi': 'https://doi.org/10.5281/zenodo.807826',
#    'doi': 'https://doi.org/10.5281/zenodo.807827',
#    'html': 'https://zenodo.org/record/807827',
#    'latest': 'https://zenodo.org/api/records/807827',
#    'latest_html': 'https://zenodo.org/record/807827',
#    'self': 'https://zenodo.org/api/records/807827'},
#   'metadata': {'access_right': 'open',
#    'access_right_category': 'success',
#    'communities': [{'id': 'biosyslit'}],
#    'creators': [{'name': 'Doğan, Sibel'},
#     {'name': 'Doğan, Salih'},
#     {'name': 'Erman, Orhan'}],
#    'description': 'FIGURE 4. Stigmaeus communis sp. nov. (Male) A. Dorsal view of idiosoma, B. Ventral view of idiosoma.',
#    'doi': '10.5281/zenodo.807827',
#    'keywords': ['Biodiversity',
#     'Taxonomy',
#     'Animalia',
#     'Arthropoda',
#     'Arachnida',
#     'Prostigmata',
#     'Stigmaeidae',
#     'Stigmaeus'],
#    'license': {'id': 'notspecified'},
#    'publication_date': '2017-12-31',
#    'related_identifiers': [{'identifier': 'http://treatment.plazi.org/id/03F087A3FFE18850FF04AE53FF7F88CA',
#      'relation': 'isCitedBy',
#      'scheme': 'url'},
#     {'identifier': '10.11646/zootaxa.4276.4.1',
#      'relation': 'isPartOf',
#      'scheme': 'doi'},
#     {'identifier': 'urn:lsid:plazi.org:pub:FFC9FFDBFFE08855FF93AC31FFA08B04',
#      'relation': 'isPartOf',
#      'scheme': 'lsid'},
#     {'identifier': 'https://zenodo.org/record/807819',
#      'relation': 'isPartOf',
#      'scheme': 'url'},
#     {'identifier': '10.5281/zenodo.807826',
#      'relation': 'isPartOf',
#      'scheme': 'doi'}],
#    'relations': {'version': [{'count': 1,
#       'index': 0,
#       'is_last': True,
#       'last_child': {'pid_type': 'recid', 'pid_value': '807827'},
#       'parent': {'pid_type': 'recid', 'pid_value': '807826'}}]},
#    'resource_type': {'subtype': 'figure', 'title': 'Figure', 'type': 'image'},
#    'title': 'FIGURE 4 in Description of five new species of the genus Stigmaeus Koch (Acari: Raphignathoidea: Stigmaeidae) from Turkey'},
#   'owners': [1161],
#   'revision': 1,
#   'updated': '2017-06-14T07:13:55.940478+00:00'},
#  {'conceptdoi': '10.5281/zenodo.807820',
#   'conceptrecid': '807820',
#   'created': '2017-06-14T07:13:46.738541+00:00',
#   'doi': '10.5281/zenodo.807821',
#   'id': 807821,
#   'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807821.svg',
#    'bucket': 'https://zenodo.org/api/files/50565cf0-2404-4efe-819b-2cceeb734889',
#    'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807820.svg',
#    'conceptdoi': 'https://doi.org/10.5281/zenodo.807820',
#    'doi': 'https://doi.org/10.5281/zenodo.807821',
#    'html': 'https://zenodo.org/record/807821',
#    'latest': 'https://zenodo.org/api/records/807821',
#    'latest_html': 'https://zenodo.org/record/807821',
#    'self': 'https://zenodo.org/api/records/807821'},
#   'metadata': {'access_right': 'open',
#    'access_right_category': 'success',
#    'communities': [{'id': 'biosyslit'}],
#    'creators': [{'name': 'Doğan, Sibel'},
#     {'name': 'Doğan, Salih'},
#     {'name': 'Erman, Orhan'}],
#    'description': 'FIGURE 1. Stigmaeus communis sp. nov. (Female) A Dorsal view of idiosoma, B. Ventral view of idiosoma.',
#    'doi': '10.5281/zenodo.807821',
#    'keywords': ['Biodiversity',
#     'Taxonomy',
#     'Animalia',
#     'Arthropoda',
#     'Arachnida',
#     'Prostigmata',
#     'Stigmaeidae',
#     'Stigmaeus'],
#    'license': {'id': 'notspecified'},
#    'publication_date': '2017-12-31',
#    'related_identifiers': [{'identifier': 'http://treatment.plazi.org/id/03F087A3FFE18850FF04AE53FF7F88CA',
#      'relation': 'isCitedBy',
#      'scheme': 'url'},
#     {'identifier': '10.11646/zootaxa.4276.4.1',
#      'relation': 'isPartOf',
#      'scheme': 'doi'},
#     {'identifier': 'urn:lsid:plazi.org:pub:FFC9FFDBFFE08855FF93AC31FFA08B04',
#      'relation': 'isPartOf',
#      'scheme': 'lsid'},
#     {'identifier': 'https://zenodo.org/record/807819',
#      'relation': 'isPartOf',
#      'scheme': 'url'},
#     {'identifier': '10.5281/zenodo.807820',
#      'relation': 'isPartOf',
#      'scheme': 'doi'}],
#    'relations': {'version': [{'count': 1,
#       'index': 0,
#       'is_last': True,
#       'last_child': {'pid_type': 'recid', 'pid_value': '807821'},
#       'parent': {'pid_type': 'recid', 'pid_value': '807820'}}]},
#    'resource_type': {'subtype': 'figure', 'title': 'Figure', 'type': 'image'},
#    'title': 'FIGURE 1 in Description of five new species of the genus Stigmaeus Koch (Acari: Raphignathoidea: Stigmaeidae) from Turkey'},
#   'owners': [1161],
#   'revision': 1,
#   'updated': '2017-06-14T07:13:46.932388+00:00'},
#  {'conceptdoi': '10.5281/zenodo.808003',
#   'conceptrecid': '808003',
#   'created': '2017-06-14T08:08:26.747617+00:00',
#   'doi': '10.5281/zenodo.808004',
#   'id': 808004,
#   'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.808004.svg',
#    'bucket': 'https://zenodo.org/api/files/e9c92b1b-d92b-4726-8d89-93f0839b96ce',
#    'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.808003.svg',
#    'conceptdoi': 'https://doi.org/10.5281/zenodo.808003',
#    'doi': 'https://doi.org/10.5281/zenodo.808004',
#    'html': 'https://zenodo.org/record/808004',
#    'latest': 'https://zenodo.org/api/records/808004',
#    'latest_html': 'https://zenodo.org/record/808004',
#    'self': 'https://zenodo.org/api/records/808004'},
#   'metadata': {'access_conditions': '<p>Visionierung auf Anfrage</p>',
#    'access_right': 'restricted',
#    'access_right_category': 'danger',
#    'communities': [{'id': 'buchjahr'}],
#    'creators': [{'name': 'Keller, Judith'}],
#    'description': '<p>Filmische Buchbesprechung zum Werk</p>\n\n<p>Zwicky, Dieter. (2016). <em>Hihi - Mein argentinischer Vater : Erzählung</em> (1. Auflage ed.). Wädenswil: Pudelundpinscher.</p>',
#    'doi': '10.5281/zenodo.808004',
#    'keywords': ['Schweizer Buchjahr',
#     'Buchjahr 2016',
#     'Buchbesprechung',
#     'Videorezension'],
#    'publication_date': '2016-09-30',
#    'related_identifiers': [{'identifier': '10.5281/zenodo.808003',
#      'relation': 'isPartOf',
#      'scheme': 'doi'}],
#    'relations': {'version': [{'count': 1,
#       'index': 0,
#       'is_last': True,
#       'last_child': {'pid_type': 'recid', 'pid_value': '808004'},
#       'parent': {'pid_type': 'recid', 'pid_value': '808003'}}]},
#    'resource_type': {'title': 'Video/Audio', 'type': 'video'},
#    'title': 'Hihi - mein argentinischer Vater / Dieter Zwicky [Viderezension]'},
#   'owners': [24712],
#   'revision': 2,
#   'updated': '2017-06-14T08:42:47.246921+00:00'},
#  {'conceptdoi': '10.5281/zenodo.807762',
#   'conceptrecid': '807762',
#   'created': '2017-06-14T03:35:46.314390+00:00',
#   'doi': '10.5281/zenodo.807763',
#   'id': 807763,
#   'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807763.svg',
#    'bucket': 'https://zenodo.org/api/files/a9c99371-ca49-463b-b279-7c7559c5ee9d',
#    'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807762.svg',
#    'conceptdoi': 'https://doi.org/10.5281/zenodo.807762',
#    'doi': 'https://doi.org/10.5281/zenodo.807763',
#    'html': 'https://zenodo.org/record/807763',
#    'latest': 'https://zenodo.org/api/records/807763',
#    'latest_html': 'https://zenodo.org/record/807763',
#    'self': 'https://zenodo.org/api/records/807763'},
#   'metadata': {'access_right': 'open',
#    'access_right_category': 'success',
#    'creators': [{'affiliation': 'McMaster University', 'name': 'icbicket'}],
#    'description': '<p>Initial release of Python code for analyzing spectrum images collected with electron energy loss spectroscopy and cathodoluminescence. The focus is on plasmonics applications (low-loss EELS), providing navigation of 3D datasets, Richardson-Lucy deconvolution, and aligning spectra and images.</p>',
#    'doi': '10.5281/zenodo.807763',
#    'license': {'id': 'other-open'},
#    'publication_date': '2017-06-14',
#    'related_identifiers': [{'identifier': 'https://github.com/icbicket/DataAnalysis/tree/v1.0.0',
#      'relation': 'isSupplementTo',
#      'scheme': 'url'},
#     {'identifier': '10.5281/zenodo.807762',
#      'relation': 'isPartOf',
#      'scheme': 'doi'}],
#    'relations': {'version': [{'count': 1,
#       'index': 0,
#       'is_last': True,
#       'last_child': {'pid_type': 'recid', 'pid_value': '807763'},
#       'parent': {'pid_type': 'recid', 'pid_value': '807762'}}]},
#    'resource_type': {'title': 'Software', 'type': 'software'},
#    'title': 'icbicket/DataAnalysis: SpectrumImagingAnalysisPy'},
#   'owners': [32726],
#   'revision': 2,
#   'updated': '2017-06-14T03:49:08.420784+00:00'},
#  {'conceptdoi': '10.5281/zenodo.807908',
#   'conceptrecid': '807908',
#   'created': '2017-06-14T07:41:39.255322+00:00',
#   'doi': '10.5281/zenodo.807909',
#   'id': 807909,
#   'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807909.svg',
#    'bucket': 'https://zenodo.org/api/files/5a3a17cb-5fd2-409e-a9c0-c47b1dc773fc',
#    'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807908.svg',
#    'conceptdoi': 'https://doi.org/10.5281/zenodo.807908',
#    'doi': 'https://doi.org/10.5281/zenodo.807909',
#    'html': 'https://zenodo.org/record/807909',
#    'latest': 'https://zenodo.org/api/records/807909',
#    'latest_html': 'https://zenodo.org/record/807909',
#    'self': 'https://zenodo.org/api/records/807909'},
#   'metadata': {'access_right': 'open',
#    'access_right_category': 'success',
#    'communities': [{'id': 'biosyslit'}],
#    'creators': [{'name': 'Wilke, Tanja'},
#     {'name': 'Ahlrichs, Wilko H.'},
#     {'name': 'Bininda-Emonds, Olaf R. P.'}],
#    'description': 'FIGURE 4. SEM photographs of the trophi of A – E S. tremula and F – J S. tremuloida (A, F, ventral; B, G dorsal; C, H lateral with the ventral rami pointing upwards; D, I unci, apical view with the ventral side of the trophus pointing upwards; E, J unci, frontal hooks and triangular platelet, latero-apical detail with the ventral side of the trophus pointing upwards). ca, cauda; cl, clava; clt, toothlike clava-lamella; dfh, dorsal frontal hook; hyp, hypopharynx; fu, fulcrum; ra, ramus; rdr, ramus distal ridge; rir, ramus inner ridge; rmr, ramus median ridge; tp, triangular platelet; un, uncus; and vfh, ventral frontal hook.',
#    'doi': '10.5281/zenodo.807909',
#    'keywords': ['Biodiversity',
#     'Taxonomy',
#     'Animalia',
#     'Rotifera',
#     'Eurotatoria',
#     'Ploima',
#     'Synchaetidae',
#     'Synchaeta'],
#    'license': {'id': 'notspecified'},
#    'publication_date': '2017-12-31',
#    'related_identifiers': [{'identifier': 'http://treatment.plazi.org/id/4606AF6BCE475C436CAAFDEBFC9BFE79',
#      'relation': 'isCitedBy',
#      'scheme': 'url'},
#     {'identifier': '10.11646/zootaxa.4276.4.3',
#      'relation': 'isPartOf',
#      'scheme': 'doi'},
#     {'identifier': 'urn:lsid:plazi.org:pub:BA3FD713CE4E5C486C3DFFCFFF89FFA9',
#      'relation': 'isPartOf',
#      'scheme': 'lsid'},
#     {'identifier': 'https://zenodo.org/record/807901',
#      'relation': 'isPartOf',
#      'scheme': 'url'},
#     {'identifier': '10.5281/zenodo.807908',
#      'relation': 'isPartOf',
#      'scheme': 'doi'}],
#    'relations': {'version': [{'count': 1,
#       'index': 0,
#       'is_last': True,
#       'last_child': {'pid_type': 'recid', 'pid_value': '807909'},
#       'parent': {'pid_type': 'recid', 'pid_value': '807908'}}]},
#    'resource_type': {'subtype': 'figure', 'title': 'Figure', 'type': 'image'},
#    'title': 'FIGURE 4 in A comprehensive and integrative re-description of Synchaeta tremula (Müller, 1786) and the newly rediscovered Synchaeta tremuloida Pourriot, 1965 (Rotifera: Synchaetidae)'},
#   'owners': [1161],
#   'revision': 1,
#   'updated': '2017-06-14T07:41:39.481980+00:00'},
#  {'conceptdoi': '10.5281/zenodo.807904',
#   'conceptrecid': '807904',
#   'created': '2017-06-14T07:41:32.004686+00:00',
#   'doi': '10.5281/zenodo.807905',
#   'id': 807905,
#   'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807905.svg',
#    'bucket': 'https://zenodo.org/api/files/e37f170c-2233-4633-ae1b-f7e55962bda8',
#    'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807904.svg',
#    'conceptdoi': 'https://doi.org/10.5281/zenodo.807904',
#    'doi': 'https://doi.org/10.5281/zenodo.807905',
#    'html': 'https://zenodo.org/record/807905',
#    'latest': 'https://zenodo.org/api/records/807905',
#    'latest_html': 'https://zenodo.org/record/807905',
#    'self': 'https://zenodo.org/api/records/807905'},
#   'metadata': {'access_right': 'open',
#    'access_right_category': 'success',
#    'communities': [{'id': 'biosyslit'}],
#    'creators': [{'name': 'Wilke, Tanja'},
#     {'name': 'Ahlrichs, Wilko H.'},
#     {'name': 'Bininda-Emonds, Olaf R. P.'}],
#    'description': 'FIGURE 2. SEM photographs of the habitus of A – C S. tremula and D – F S. tremuloida (A, D, dorsally; B, E, apically; C, F, anal-pseudosegment and foot with toes, lateral view). Scale bars: 10 µm. aps, anal-pseudosegment; ar, apical receptor; asc, ampulla shaped cilia; au, auricle; da, dorsal antenna; dcf, dorsal ciliary field; dlcf, dorsolateral ciliary field; dst, dorsal stylus; gm, gland meatus; la, lateral antennae; lcf, lateral ciliary field; lst, lateral stylus; mr 1 – 3, mouth receptors; and vlcf, ventrolateral ciliary field.',
#    'doi': '10.5281/zenodo.807905',
#    'keywords': ['Biodiversity',
#     'Taxonomy',
#     'Animalia',
#     'Rotifera',
#     'Eurotatoria',
#     'Ploima',
#     'Synchaetidae',
#     'Synchaeta'],
#    'license': {'id': 'notspecified'},
#    'publication_date': '2017-12-31',
#    'related_identifiers': [{'identifier': 'http://treatment.plazi.org/id/4606AF6BCE4C5C416CAAF94AFE58FE79',
#      'relation': 'isCitedBy',
#      'scheme': 'url'},
#     {'identifier': '10.11646/zootaxa.4276.4.3',
#      'relation': 'isPartOf',
#      'scheme': 'doi'},
#     {'identifier': 'urn:lsid:plazi.org:pub:BA3FD713CE4E5C486C3DFFCFFF89FFA9',
#      'relation': 'isPartOf',
#      'scheme': 'lsid'},
#     {'identifier': 'https://zenodo.org/record/807901',
#      'relation': 'isPartOf',
#      'scheme': 'url'},
#     {'identifier': '10.5281/zenodo.807904',
#      'relation': 'isPartOf',
#      'scheme': 'doi'}],
#    'relations': {'version': [{'count': 1,
#       'index': 0,
#       'is_last': True,
#       'last_child': {'pid_type': 'recid', 'pid_value': '807905'},
#       'parent': {'pid_type': 'recid', 'pid_value': '807904'}}]},
#    'resource_type': {'subtype': 'figure', 'title': 'Figure', 'type': 'image'},
#    'title': 'FIGURE 2 in A comprehensive and integrative re-description of Synchaeta tremula (Müller, 1786) and the newly rediscovered Synchaeta tremuloida Pourriot, 1965 (Rotifera: Synchaetidae)'},
#   'owners': [1161],
#   'revision': 1,
#   'updated': '2017-06-14T07:41:32.208116+00:00'},
#  {'conceptdoi': '10.5281/zenodo.807944',
#   'conceptrecid': '807944',
#   'created': '2017-06-14T07:50:23.419438+00:00',
#   'doi': '10.5281/zenodo.807945',
#   'id': 807945,
#   'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807945.svg',
#    'bucket': 'https://zenodo.org/api/files/0a4a6406-5031-4b5e-bd6c-5142ec9fc715',
#    'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807944.svg',
#    'conceptdoi': 'https://doi.org/10.5281/zenodo.807944',
#    'doi': 'https://doi.org/10.5281/zenodo.807945',
#    'html': 'https://zenodo.org/record/807945',
#    'latest': 'https://zenodo.org/api/records/807945',
#    'latest_html': 'https://zenodo.org/record/807945',
#    'self': 'https://zenodo.org/api/records/807945'},
#   'metadata': {'access_right': 'open',
#    'access_right_category': 'success',
#    'communities': [{'id': 'biosyslit'}],
#    'creators': [{'name': 'Marusik'}, {'name': 'Omelko'}, {'name': 'Koponen'}],
#    'description': 'Figs 4 ‒ 9. Male of Gongylidioides ussuricus. 4 ‒ habitus, lateral; 5 – the same, dorsal; 6 – palp, retrolateral; 7 – palp, ventral; 8 – palp, prolateral; 9 – palp, dorsal. Scale = 0.2 mm if not otherwise indicated.',
#    'doi': '10.5281/zenodo.807945',
#    'keywords': ['Biodiversity',
#     'Taxonomy',
#     'Animalia',
#     'Arthropoda',
#     'Arachnida',
#     'Araneae',
#     'Linyphiidae',
#     'Gongylidioides'],
#    'license': {'id': 'notspecified'},
#    'publication_date': '2016-12-31',
#    'related_identifiers': [{'identifier': 'http://treatment.plazi.org/id/420AC67D7600DB17FFAF0326C9C1C368',
#      'relation': 'isCitedBy',
#      'scheme': 'url'},
#     {'identifier': '10.5281/zenodo.807941',
#      'relation': 'isPartOf',
#      'scheme': 'doi'},
#     {'identifier': 'urn:lsid:plazi.org:pub:BE33BE057603DB13FFDE024BCB37C220',
#      'relation': 'isPartOf',
#      'scheme': 'lsid'},
#     {'identifier': 'https://zenodo.org/record/807941',
#      'relation': 'isPartOf',
#      'scheme': 'url'},
#     {'identifier': '10.5281/zenodo.807944',
#      'relation': 'isPartOf',
#      'scheme': 'doi'}],
#    'relations': {'version': [{'count': 1,
#       'index': 0,
#       'is_last': True,
#       'last_child': {'pid_type': 'recid', 'pid_value': '807945'},
#       'parent': {'pid_type': 'recid', 'pid_value': '807944'}}]},
#    'resource_type': {'subtype': 'figure', 'title': 'Figure', 'type': 'image'},
#    'title': 'Figs 4 ‒ 9 in Rare And New For The Fauna Of The Russian Far East Spiders (Aranei)'},
#   'owners': [1161],
#   'revision': 1,
#   'updated': '2017-06-14T07:50:23.618449+00:00'},
#  {'conceptdoi': '10.5281/zenodo.807946',
#   'conceptrecid': '807946',
#   'created': '2017-06-14T07:50:26.261471+00:00',
#   'doi': '10.5281/zenodo.807947',
#   'id': 807947,
#   'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807947.svg',
#    'bucket': 'https://zenodo.org/api/files/b0ffc8e8-5620-42e0-96ee-e67b8d5cffad',
#    'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807946.svg',
#    'conceptdoi': 'https://doi.org/10.5281/zenodo.807946',
#    'doi': 'https://doi.org/10.5281/zenodo.807947',
#    'html': 'https://zenodo.org/record/807947',
#    'latest': 'https://zenodo.org/api/records/807947',
#    'latest_html': 'https://zenodo.org/record/807947',
#    'self': 'https://zenodo.org/api/records/807947'},
#   'metadata': {'access_right': 'open',
#    'access_right_category': 'success',
#    'communities': [{'id': 'biosyslit'}],
#    'creators': [{'name': 'Marusik'}, {'name': 'Omelko'}, {'name': 'Koponen'}],
#    'description': 'Figs 10 ‒ 14. Male and female of " Oreonetides " longembolus. 10 – male habitus, dorsal; 11 – female habitus, dorsal; 12 – epigyne, ventral; 13, 14 – male palp, pro- and retrolateral. Scale = 0.2 mm if not otherwise indicated.',
#    'doi': '10.5281/zenodo.807947',
#    'keywords': ['Biodiversity',
#     'Taxonomy',
#     'Animalia',
#     'Arthropoda',
#     'Arachnida',
#     'Araneae',
#     'Linyphiidae',
#     'Oreonetides'],
#    'license': {'id': 'notspecified'},
#    'publication_date': '2016-12-31',
#    'related_identifiers': [{'identifier': 'http://treatment.plazi.org/id/420AC67D7607DB15FFAF0326CA39C098',
#      'relation': 'isCitedBy',
#      'scheme': 'url'},
#     {'identifier': '10.5281/zenodo.807941',
#      'relation': 'isPartOf',
#      'scheme': 'doi'},
#     {'identifier': 'urn:lsid:plazi.org:pub:BE33BE057603DB13FFDE024BCB37C220',
#      'relation': 'isPartOf',
#      'scheme': 'lsid'},
#     {'identifier': 'https://zenodo.org/record/807941',
#      'relation': 'isPartOf',
#      'scheme': 'url'},
#     {'identifier': '10.5281/zenodo.807946',
#      'relation': 'isPartOf',
#      'scheme': 'doi'}],
#    'relations': {'version': [{'count': 1,
#       'index': 0,
#       'is_last': True,
#       'last_child': {'pid_type': 'recid', 'pid_value': '807947'},
#       'parent': {'pid_type': 'recid', 'pid_value': '807946'}}]},
#    'resource_type': {'subtype': 'figure', 'title': 'Figure', 'type': 'image'},
#    'title': 'Figs 10 ‒ 14 in Rare And New For The Fauna Of The Russian Far East Spiders (Aranei)'},
#   'owners': [1161],
#   'revision': 1,
#   'updated': '2017-06-14T07:50:26.441983+00:00'},
#  {'conceptdoi': '10.5281/zenodo.807894',
#   'conceptrecid': '807894',
#   'created': '2017-06-14T07:39:16.859976+00:00',
#   'doi': '10.5281/zenodo.807895',
#   'id': 807895,
#   'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807895.svg',
#    'bucket': 'https://zenodo.org/api/files/24cdfb9c-c27d-4e48-8f19-d2e40b12a3dc',
#    'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807894.svg',
#    'conceptdoi': 'https://doi.org/10.5281/zenodo.807894',
#    'doi': 'https://doi.org/10.5281/zenodo.807895',
#    'html': 'https://zenodo.org/record/807895',
#    'latest': 'https://zenodo.org/api/records/807895',
#    'latest_html': 'https://zenodo.org/record/807895',
#    'self': 'https://zenodo.org/api/records/807895'},
#   'metadata': {'access_conditions': '<p>Visionierung auf Anfrage</p>',
#    'access_right': 'restricted',
#    'access_right_category': 'danger',
#    'communities': [{'id': 'buchjahr'}],
#    'creators': [{'name': 'Sidler, Maja'}],
#    'description': '<p>Filmische Buchbesprechung zum Werk</p>\n\n<p>Fricker, Ursula. (2016). <em>Lügen von gestern und heute : Roman</em> (Originalausgabe ed.). München: Dtv.</p>',
#    'doi': '10.5281/zenodo.807895',
#    'keywords': ['Schweizer Buchjahr',
#     'Buchjahr 2016',
#     'Buchbesprechung',
#     'Videorezension'],
#    'publication_date': '2016-09-30',
#    'related_identifiers': [{'identifier': '10.5281/zenodo.807894',
#      'relation': 'isPartOf',
#      'scheme': 'doi'}],
#    'relations': {'version': [{'count': 1,
#       'index': 0,
#       'is_last': True,
#       'last_child': {'pid_type': 'recid', 'pid_value': '807895'},
#       'parent': {'pid_type': 'recid', 'pid_value': '807894'}}]},
#    'resource_type': {'title': 'Video/Audio', 'type': 'video'},
#    'title': 'Lügen von gestern und heute / Ursula Fricker [Videorezension]'},
#   'owners': [24712],
#   'revision': 3,
#   'updated': '2017-06-14T07:48:12.392489+00:00'},
#  {'conceptdoi': '10.5281/zenodo.807920',
#   'conceptrecid': '807920',
#   'created': '2017-06-14T07:45:34.489774+00:00',
#   'doi': '10.5281/zenodo.807921',
#   'id': 807921,
#   'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807921.svg',
#    'bucket': 'https://zenodo.org/api/files/80e7410e-1073-4970-8e49-cd23bb3e35b4',
#    'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807920.svg',
#    'conceptdoi': 'https://doi.org/10.5281/zenodo.807920',
#    'doi': 'https://doi.org/10.5281/zenodo.807921',
#    'html': 'https://zenodo.org/record/807921',
#    'latest': 'https://zenodo.org/api/records/807921',
#    'latest_html': 'https://zenodo.org/record/807921',
#    'self': 'https://zenodo.org/api/records/807921'},
#   'metadata': {'access_conditions': '<p>Visionierung auf Anfrage</p>',
#    'access_right': 'restricted',
#    'access_right_category': 'danger',
#    'communities': [{'id': 'buchjahr'}],
#    'creators': [{'name': 'Hug, Halina'}],
#    'description': '<p>Filmische Buchbesprechung zum Werk</p>\n\n<p>Langenegger, Lorenz. (2016). <em>Dorffrieden : Roman</em>. Salzburg: Jung und Jung.</p>',
#    'doi': '10.5281/zenodo.807921',
#    'keywords': ['Schweizer Buchjahr',
#     'Buchjahr 2016',
#     'Buchbesprechung',
#     'Videorezension'],
#    'publication_date': '2016-09-30',
#    'related_identifiers': [{'identifier': '10.5281/zenodo.807920',
#      'relation': 'isPartOf',
#      'scheme': 'doi'}],
#    'relations': {'version': [{'count': 1,
#       'index': 0,
#       'is_last': True,
#       'last_child': {'pid_type': 'recid', 'pid_value': '807921'},
#       'parent': {'pid_type': 'recid', 'pid_value': '807920'}}]},
#    'resource_type': {'title': 'Video/Audio', 'type': 'video'},
#    'title': 'Dorffrieden / Lorenz Langenegger [Videorezension]'},
#   'owners': [24712],
#   'revision': 2,
#   'updated': '2017-06-14T07:48:57.864089+00:00'},
#  {'conceptdoi': '10.5281/zenodo.807940',
#   'conceptrecid': '807940',
#   'created': '2017-06-14T07:50:56.493766+00:00',
#   'doi': '10.5281/zenodo.807941',
#   'id': 807941,
#   'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807941.svg',
#    'bucket': 'https://zenodo.org/api/files/94100d8e-33ae-4fa9-ae24-a5d11fb8f298',
#    'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807940.svg',
#    'conceptdoi': 'https://doi.org/10.5281/zenodo.807940',
#    'doi': 'https://doi.org/10.5281/zenodo.807941',
#    'html': 'https://zenodo.org/record/807941',
#    'latest': 'https://zenodo.org/api/records/807941',
#    'latest_html': 'https://zenodo.org/record/807941',
#    'self': 'https://zenodo.org/api/records/807941'},
#   'metadata': {'access_right': 'closed',
#    'access_right_category': 'danger',
#    'communities': [{'id': 'biosyslit'}],
#    'creators': [{'name': 'Marusik'}, {'name': 'Omelko'}, {'name': 'Koponen'}],
#    'description': 'Marusik, Omelko, Koponen (2016): Rare And New For The Fauna Of The Russian Far East Spiders (Aranei). Far Eastern Entomologist 317: 1-15, DOI: 10.5281/zenodo.807941, URL: http/urn:lsid:zoobank.org:pub:3B5BDD6C-20E4-4792-B524-EF26D01F0865',
#    'doi': '10.5281/zenodo.807941',
#    'journal': {'pages': '1-15',
#     'title': 'Far Eastern Entomologist',
#     'volume': '317'},
#    'keywords': ['Biodiversity',
#     'Taxonomy',
#     'Animalia',
#     'Arthropoda',
#     'Arachnida',
#     'Araneae',
#     'Linyphiidae',
#     'Mimetidae',
#     'Tetragnathidae',
#     'Theridiidae'],
#    'publication_date': '2016-12-31',
#    'references': ['Eskov, K.Y. 1984. New and little known genera and species of spiders (Aranei, Linyphiidae) from the Far East. Zoologicheskii Zhurnal, 63(9): 1337-1344. [In Russian].',
#     'Eskov, K.Y. 1991. On the taxonomy and zoogeography of the spider genera Maro and Oreonetides (Aranei, Linyphiidae). Zoologicheskii Zhurnal, 70(4): 45-54. [In Russian].',
#     'Eskov, K.Y. 1992. A restudy of the generic composition of the linyphiid spider fauna of the Far East (Araneida: Linyphiidae). Entomologica Scandinavica, 23: 153-168.',
#     'Eskov, K.Y. 1994. Catalogue of the linyphiid spiders of northern Asia (Arachnida, Araneae, Linyphiidae). Pensoft Publishers, Sofia. 144 pp.',
#     'Hayashi, T. 1986. A new Japanese spider of the genus Agroeca (Araneae: Clubionidae). Proceedings of the Japanese Society of Systematic Zoology, 33: 23-28.',
#     'Kamura, T. & Hayashi, T. 2009. Liocranidae. P. 549-550. In: Ono, H. (ed.). The Spiders of Japan with keys to the families and genera and illustrations of the species. Tokai University Press, Kanagawa.',
#     'Kim, J. P., Kim, S. D. & Lee, Y. B. 1999. A revisional study of the Korean spiders, family Tetragnathidae Menge, 186 6 (Arachnida: Araneae). Korean Arachnology, 15(2): 41-100.',
#     'Knoflach, B. 1999. The comb-footed spider genera Neottiura and Coleosoma in Europe (Araneae, Theridiidae). Mitteilungen der Schweizerischen Entomologischen Gesellschaft, 72: 341-371.',
#     'Kronestedt, T., Marusik, Y.M. & Omelko, M.M. 2014. Studies on species of Holarctic Pardosa groups (Araneae, Lycosidae). VIII. The Palearctic species of the Pardosa nigra group. Zootaxa, 3894(1): 33-60. DOI: http//doi.org/10.11646/zootaxa.3894.1.5',
#     'Marusik, Y.M. 1989. New data on the fauna and synonymy of the USSR spiders (Arachnida, Aranei). P. 39-52. In: Lange, A.B. (ed.) Fauna i Ekologiy Paukov i Skorpionov: Arakhnologicheskii Sbornik. Akademia Nauk SSSR, Moscow. [In Russian].',
#     'Marusik, Y.M., Azarkina, G.N. & Koponen, S. 2004. A survey of east Palearctic Lycosidae (Aranei). II. Genus Acantholycosa F. Dahl, 1908 and related new genera. Arthropoda Selecta, 12(2): 101-148.',
#     'Marusik, Y.M. & Koponen, S. 2000. New data on spiders (Aranei) from the Maritime Province, Russian Far East. Arthropoda Selecta, 9(1): 55-68.',
#     'Marusik, Y.M. & Koponen, S. 2008. Obituary. Michael Ilmari Saaristo (1938-2008). Arthropoda Selecta, 17(1): 4-16.',
#     'Marusik Yu.M., Mikhailov K.G. & Omelko M.M. 2015a. Taxonomic notes on spiders (Arachnida: Aranei) from the Russian Far East. Arthropoda Selecta, 24(1): 117-124.',
#     'Marusik Y.M., Omelko M.M., Simonov P.S. & Koponen S. 2015b. New data about orbweaving spiders (Aranei: Araneidae and Tetragnathidae) from the Russian Far East. Arthropoda Selecta, 24(2): 207-214.',
#     'Mikhailov, K.G. 2013. The spiders (Arachnida: Aranei) of Russia and adjacent countries: a non-annotated checklist. Arthropoda Selecta, Supplement, 3: 1-262.',
#     'Mikhailov, K.G. & Temereva, E.N. 2015. Spiders (Aranei) of Vostok Biological Station, Maritime Province, Russia. Arthropoda Selecta, 24(4): 473-475.',
#     'Saaristo, M.I. 1971. Revision of the genus Maro O.P.-Cambridge (Araneae, Linyphiidae). Annales Zoologici Fennici, 8: 463-482.',
#     'Song, D.X., Zhu, M.S. & Chen, J. 1999. The Spiders of China. Hebei University of Science and Techology Publishing House, Shijiazhuang. 640 pp.',
#     'Tanasevitch, A.V. 2006. New or little-known Maro O.P.-Cambridge from Siberia and the Russian Far East (Aranei: Linyphiidae: Micronetinae). Arthropoda Selecta, 14(3): 259- 268.',
#     'Tanikawa, A. 2007. An identification guide to the Japanese spiders of the families Araneidae, Nephilidae and Tetragnathidae. Arachnological Society of Japan. 121 pp.',
#     'Tanikawa, A. 2009. Hersiliidae. Nephilidae, Tetragnathidae, Araneidae. P. 149, 403-463. In: Ono, H. (ed.). The Spiders of Japan with keys to the families and genera and illustrations of the species. Tokai University Press, Kanagawa.',
#     'World Spider Catalog. 2016. World Spider Catalog, version 16.5. Natural History Museum Bern. Available from: http://wsc.nmbe.ch (Accessed 30 January 2 015).',
#     'Wunderlich, J. & Li, S.Q. 1995. Three new spider species and one new genus (family Linyphiidae) from China (Arachnida: Araneae). Beitrage zur Araneologie, 4: 335-342.',
#     'Yoshida, H. & Tanikawa, A. 2009. Mimetidae. P. 251-252. In: Ono, H. (ed.). The Spiders of Japan with keys to the families and genera and illustrations of the species. Tokai University Press, Kanagawa.',
#     'Yoshida, H. 2009a. Theridiidae. P. 356-393. In: Ono, H. (Ed.). The Spiders of Japan with keys to the families and genera and illustrations of the species. Tokai University Press, Kanagawa.',
#     'Yoshida, H. 2009b. The spider genus Leucauge (Araneae: Tetragnathidae) from Taiwan. Acta Arachnologica, Tokyo, 58(1): 11-18.',
#     'Zhu, M.S., Song, D.X. & Zhang, J.X. 2003. Fauna Sinica: Invertebrata Vol. 35: Arachnida: Araneae: Tetragnathidae. Science Press, Beijing. vii + 418 pp.'],
#    'related_identifiers': [{'identifier': 'http://treatment.plazi.org/id/420AC67D7601DB11FE1D0382C993C3C1',
#      'relation': 'hasPart',
#      'scheme': 'url'},
#     {'identifier': 'http://treatment.plazi.org/id/420AC67D7601DB10FFAC004DCAF7C367',
#      'relation': 'hasPart',
#      'scheme': 'url'},
#     {'identifier': 'http://treatment.plazi.org/id/420AC67D7600DB17FFAF0326C9C1C368',
#      'relation': 'hasPart',
#      'scheme': 'url'},
#     {'identifier': 'http://treatment.plazi.org/id/420AC67D7607DB15FFAF0326CA39C098',
#      'relation': 'hasPart',
#      'scheme': 'url'},
#     {'identifier': 'http://treatment.plazi.org/id/420AC67D7605DB15FFAF014CCBAEC694',
#      'relation': 'hasPart',
#      'scheme': 'url'},
#     {'identifier': 'http://treatment.plazi.org/id/420AC67D7605DB14FFAF0749C901C3A0',
#      'relation': 'hasPart',
#      'scheme': 'url'},
#     {'identifier': 'http://treatment.plazi.org/id/420AC67D7604DB1BFFAF0746CA3FC3E2',
#      'relation': 'hasPart',
#      'scheme': 'url'},
#     {'identifier': 'http://treatment.plazi.org/id/420AC67D760BDB1AFFAF0776CA4FC7F6',
#      'relation': 'hasPart',
#      'scheme': 'url'},
#     {'identifier': 'http://treatment.plazi.org/id/420AC67D7609DB19FFAF067FC902C7C2',
#      'relation': 'hasPart',
#      'scheme': 'url'},
#     {'identifier': 'http://treatment.plazi.org/id/420AC67D7608DB18FEE4028ECB83C348',
#      'relation': 'hasPart',
#      'scheme': 'url'},
#     {'identifier': 'http://treatment.plazi.org/id/420AC67D760FDB1FFFAF02DCC8FBC063',
#      'relation': 'hasPart',
#      'scheme': 'url'},
#     {'identifier': 'http://treatment.plazi.org/id/420AC67D760FDB1EFFAF0761CB83C3E2',
#      'relation': 'hasPart',
#      'scheme': 'url'},
#     {'identifier': 'Kronestedt,T.,Marusik,Y.M.&Omelko,M.M.2014.StudiesonspeciesofHolarcticPardosagroups(Araneae,Lycosidae).VIII.ThePalearcticspeciesofthePardosanigragroup.Zootaxa,3894(1):33-60.DOI:http//doi.org/10.11646/zootaxa.3894.1.5',
#      'relation': 'cites',
#      'scheme': 'handle'},
#     {'identifier': '10.5281/zenodo.807943',
#      'relation': 'hasPart',
#      'scheme': 'doi'},
#     {'identifier': 'urn:lsid:plazi.org:fig:2-130-989-779-1385',
#      'relation': 'hasPart',
#      'scheme': 'lsid'},
#     {'identifier': 'http://zenodo.org/record/807943',
#      'relation': 'hasPart',
#      'scheme': 'url'},
#     {'identifier': '10.5281/zenodo.807945',
#      'relation': 'hasPart',
#      'scheme': 'doi'},
#     {'identifier': 'urn:lsid:plazi.org:fig:3-134-995-578-1422',
#      'relation': 'hasPart',
#      'scheme': 'lsid'},
#     {'identifier': 'http://zenodo.org/record/807945',
#      'relation': 'hasPart',
#      'scheme': 'url'},
#     {'identifier': '10.5281/zenodo.807947',
#      'relation': 'hasPart',
#      'scheme': 'doi'},
#     {'identifier': 'urn:lsid:plazi.org:fig:4-115-962-630-1407',
#      'relation': 'hasPart',
#      'scheme': 'lsid'},
#     {'identifier': 'http://zenodo.org/record/807947',
#      'relation': 'hasPart',
#      'scheme': 'url'},
#     {'identifier': '10.5281/zenodo.807949',
#      'relation': 'hasPart',
#      'scheme': 'doi'},
#     {'identifier': 'urn:lsid:plazi.org:fig:5-113-982-144-1187',
#      'relation': 'hasPart',
#      'scheme': 'lsid'},
#     {'identifier': 'http://zenodo.org/record/807949',
#      'relation': 'hasPart',
#      'scheme': 'url'},
#     {'identifier': '10.5281/zenodo.807951',
#      'relation': 'hasPart',
#      'scheme': 'doi'},
#     {'identifier': 'urn:lsid:plazi.org:fig:7-232-899-415-1138',
#      'relation': 'hasPart',
#      'scheme': 'lsid'},
#     {'identifier': 'http://zenodo.org/record/807951',
#      'relation': 'hasPart',
#      'scheme': 'url'},
#     {'identifier': '10.5281/zenodo.807953',
#      'relation': 'hasPart',
#      'scheme': 'doi'},
#     {'identifier': 'urn:lsid:plazi.org:fig:8-147-980-454-1182',
#      'relation': 'hasPart',
#      'scheme': 'lsid'},
#     {'identifier': 'http://zenodo.org/record/807953',
#      'relation': 'hasPart',
#      'scheme': 'url'},
#     {'identifier': '10.5281/zenodo.807955',
#      'relation': 'hasPart',
#      'scheme': 'doi'},
#     {'identifier': 'urn:lsid:plazi.org:fig:10-159-962-160-980',
#      'relation': 'hasPart',
#      'scheme': 'lsid'},
#     {'identifier': 'http://zenodo.org/record/807955',
#      'relation': 'hasPart',
#      'scheme': 'url'},
#     {'identifier': '10.5281/zenodo.807957',
#      'relation': 'hasPart',
#      'scheme': 'doi'},
#     {'identifier': 'urn:lsid:plazi.org:fig:11-147-978-375-1422',
#      'relation': 'hasPart',
#      'scheme': 'lsid'},
#     {'identifier': 'http://zenodo.org/record/807957',
#      'relation': 'hasPart',
#      'scheme': 'url'},
#     {'identifier': '10.5281/zenodo.807959',
#      'relation': 'hasPart',
#      'scheme': 'doi'},
#     {'identifier': 'urn:lsid:plazi.org:fig:12-150-971-596-1186',
#      'relation': 'hasPart',
#      'scheme': 'lsid'},
#     {'identifier': 'http://zenodo.org/record/807959',
#      'relation': 'hasPart',
#      'scheme': 'url'},
#     {'identifier': '10.5281/zenodo.807940',
#      'relation': 'isPartOf',
#      'scheme': 'doi'}],
#    'relations': {'version': [{'count': 1,
#       'index': 0,
#       'is_last': True,
#       'last_child': {'pid_type': 'recid', 'pid_value': '807941'},
#       'parent': {'pid_type': 'recid', 'pid_value': '807940'}}]},
#    'resource_type': {'subtype': 'article',
#     'title': 'Journal article',
#     'type': 'publication'},
#    'title': 'Rare And New For The Fauna Of The Russian Far East Spiders (Aranei)'},
#   'owners': [1161],
#   'revision': 1,
#   'updated': '2017-06-14T07:50:56.694540+00:00'},
#  {'conceptdoi': '10.5281/zenodo.807972',
#   'conceptrecid': '807972',
#   'created': '2017-06-14T07:53:13.747931+00:00',
#   'doi': '10.5281/zenodo.807973',
#   'id': 807973,
#   'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807973.svg',
#    'bucket': 'https://zenodo.org/api/files/d3e8f561-62c8-445b-9321-7e380e49687d',
#    'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807972.svg',
#    'conceptdoi': 'https://doi.org/10.5281/zenodo.807972',
#    'doi': 'https://doi.org/10.5281/zenodo.807973',
#    'html': 'https://zenodo.org/record/807973',
#    'latest': 'https://zenodo.org/api/records/807973',
#    'latest_html': 'https://zenodo.org/record/807973',
#    'self': 'https://zenodo.org/api/records/807973'},
#   'metadata': {'access_right': 'open',
#    'access_right_category': 'success',
#    'communities': [{'id': 'biosyslit'}],
#    'creators': [{'name': 'Monniot, Françoise'},
#     {'name': 'López-Legentil, Susanna'}],
#    'description': 'FIGURE 1. Fimbrora calsubia. A and B, ventral and dorsal sides of a specimen. C, neural area. D, detail of the ramified tissues of the posterior part of the abdomen stained with hemalum.',
#    'doi': '10.5281/zenodo.807973',
#    'keywords': ['Biodiversity',
#     'Taxonomy',
#     'Animalia',
#     'Chordata',
#     'Ascidiacea',
#     'Enterogona',
#     'Ascidiidae',
#     'Fimbrora'],
#    'license': {'id': 'notspecified'},
#    'publication_date': '2017-12-31',
#    'related_identifiers': [{'identifier': 'http://treatment.plazi.org/id/D02201375E04D10F35AD84FA802C39A2',
#      'relation': 'isCitedBy',
#      'scheme': 'url'},
#     {'identifier': '10.11646/zootaxa.4276.4.5',
#      'relation': 'isPartOf',
#      'scheme': 'doi'},
#     {'identifier': 'urn:lsid:plazi.org:pub:2C1B794F5E06D10B353A8426813C3A4F',
#      'relation': 'isPartOf',
#      'scheme': 'lsid'},
#     {'identifier': 'https://zenodo.org/record/807971',
#      'relation': 'isPartOf',
#      'scheme': 'url'},
#     {'identifier': '10.5281/zenodo.807972',
#      'relation': 'isPartOf',
#      'scheme': 'doi'}],
#    'relations': {'version': [{'count': 1,
#       'index': 0,
#       'is_last': True,
#       'last_child': {'pid_type': 'recid', 'pid_value': '807973'},
#       'parent': {'pid_type': 'recid', 'pid_value': '807972'}}]},
#    'resource_type': {'subtype': 'figure', 'title': 'Figure', 'type': 'image'},
#    'title': 'FIGURE 1. Fimbrora calsubia. A and B in Deep-sea ascidians from Papua New Guinea'},
#   'owners': [1161],
#   'revision': 1,
#   'updated': '2017-06-14T07:53:13.968550+00:00'},
#  {'conceptdoi': '10.5281/zenodo.807952',
#   'conceptrecid': '807952',
#   'created': '2017-06-14T07:50:38.406749+00:00',
#   'doi': '10.5281/zenodo.807953',
#   'id': 807953,
#   'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807953.svg',
#    'bucket': 'https://zenodo.org/api/files/5e0257b5-d795-4da7-b90c-cfc3defbac85',
#    'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807952.svg',
#    'conceptdoi': 'https://doi.org/10.5281/zenodo.807952',
#    'doi': 'https://doi.org/10.5281/zenodo.807953',
#    'html': 'https://zenodo.org/record/807953',
#    'latest': 'https://zenodo.org/api/records/807953',
#    'latest_html': 'https://zenodo.org/record/807953',
#    'self': 'https://zenodo.org/api/records/807953'},
#   'metadata': {'access_right': 'open',
#    'access_right_category': 'success',
#    'communities': [{'id': 'biosyslit'}],
#    'creators': [{'name': 'Marusik'}, {'name': 'Omelko'}, {'name': 'Koponen'}],
#    'description': 'Figs 28 - 31. Female of Mimetus testaceus. 28, 29 – habitus, dorsal and lateral; 30, 31 – epigyne, caudal and ventral. Scale = 0.2 mm if not otherwise indicated.',
#    'doi': '10.5281/zenodo.807953',
#    'keywords': ['Biodiversity',
#     'Taxonomy',
#     'Animalia',
#     'Arthropoda',
#     'Arachnida',
#     'Araneae',
#     'Mimetidae',
#     'Mimetus'],
#    'license': {'id': 'notspecified'},
#    'publication_date': '2016-12-31',
#    'related_identifiers': [{'identifier': 'http://treatment.plazi.org/id/420AC67D7604DB1BFFAF0746CA3FC3E2',
#      'relation': 'isCitedBy',
#      'scheme': 'url'},
#     {'identifier': '10.5281/zenodo.807941',
#      'relation': 'isPartOf',
#      'scheme': 'doi'},
#     {'identifier': 'urn:lsid:plazi.org:pub:BE33BE057603DB13FFDE024BCB37C220',
#      'relation': 'isPartOf',
#      'scheme': 'lsid'},
#     {'identifier': 'https://zenodo.org/record/807941',
#      'relation': 'isPartOf',
#      'scheme': 'url'},
#     {'identifier': '10.5281/zenodo.807952',
#      'relation': 'isPartOf',
#      'scheme': 'doi'}],
#    'relations': {'version': [{'count': 1,
#       'index': 0,
#       'is_last': True,
#       'last_child': {'pid_type': 'recid', 'pid_value': '807953'},
#       'parent': {'pid_type': 'recid', 'pid_value': '807952'}}]},
#    'resource_type': {'subtype': 'figure', 'title': 'Figure', 'type': 'image'},
#    'title': 'Figs 28 - 31 in Rare And New For The Fauna Of The Russian Far East Spiders (Aranei)'},
#   'owners': [1161],
#   'revision': 1,
#   'updated': '2017-06-14T07:50:38.617126+00:00'},
#  {'conceptrecid': '807960',
#   'created': '2017-06-14T07:52:08.229754+00:00',
#   'doi': '10.1080/09397140.2015.1095525',
#   'id': 807961,
#   'links': {'badge': 'https://zenodo.org/badge/doi/10.1080/09397140.2015.1095525.svg',
#    'bucket': 'https://zenodo.org/api/files/7ae2adcb-df5a-4c04-8c7c-f5486d9738cb',
#    'doi': 'https://doi.org/10.1080/09397140.2015.1095525',
#    'html': 'https://zenodo.org/record/807961',
#    'latest': 'https://zenodo.org/api/records/807961',
#    'latest_html': 'https://zenodo.org/record/807961',
#    'self': 'https://zenodo.org/api/records/807961'},
#   'metadata': {'access_right': 'closed',
#    'access_right_category': 'danger',
#    'communities': [{'id': 'biosyslit'}],
#    'creators': [{'name': 'Zonstein, Sergei'},
#     {'name': 'Marusik, Yuri'},
#     {'name': 'Omelko, Mikhail'}],
#    'description': 'Zonstein, Sergei, Marusik, Yuri, Omelko, Mikhail (2015): A survey of spider taxa new to Israel (Arachnida: Araneae). Zoology in the Middle East 61 (4): 372-385, DOI: 10.1080/09397140.2015.1095525',
#    'doi': '10.1080/09397140.2015.1095525',
#    'journal': {'issue': '4',
#     'pages': '372-385',
#     'title': 'Zoology in the Middle East',
#     'volume': '61'},
#    'keywords': ['Biodiversity',
#     'Taxonomy',
#     'Animalia',
#     'Arthropoda',
#     'Arachnida',
#     'Araneae',
#     'Dictynidae',
#     'Hahniidae',
#     'Linyphiidae',
#     'Liocranidae',
#     'Lycosidae',
#     'Mimetidae',
#     'Mysmenidae',
#     'Pholcidae',
#     'Phyxelididae',
#     'Prodidomidae',
#     'Salticidae',
#     'Theridiidae',
#     'Corinnidae',
#     'Uloboridae'],
#    'publication_date': '2015-12-31',
#    'references': ['Bayram, A., Kunt, K. B., & Danisman, T. (2014): The checklist of the spiders of Turkey. Version 2014. www.kazimcapaci.com/spidersofturkey.htm [accessed 11 January 2015].',
#     'Bosmans, R., Baert, L., Bosselaers, J., De Koninck, H, Maelfait, J.-P. & Van Keer, J. (2009): Spiders of Lesbos (Greece). Nieuwsbrief van de Belgische Arachnologische Vereniging, 24 (suppl.), 1-70.',
#     'Bosmans, R. (2011): On some new or rare spider species from Lesbos, Greece (Araneae: Agelenidae, Amaurobiidae, Corinnidae, Gnaphosidae, Liocranidae). Arachnologische Mitteilungen, 40, 15-22.',
#     'Cambridge, O. P. (1876): Catalogue of a collection of spiders made in Egypt, with descriptions of new species and characters of a new genus. Proceedings of the Zoological Society of London, 1876, 541-630.',
#     "Denis, J. (1947): Spiders. In: Results of the Armstrong College expedition to Siwa Oasis (Libyan desert), 1935. Bulletin de la Societe Fouad Ier d'Entomologie, 31, 17-103.",
#     'Dunin, P. M., Buchar, J., & Absolon, K. (1986): Die dritte Palaarktische Aulonia -Art: Aulonia kratochvili sp. n. (Araneida, Lycosidae). Vestnik Ceskoslovenske Zoologicke Spolecnosti v Praze, 50, 28-32.',
#     'Griswold, C. E. (1990): A revision and phylogenetic analysis of the spider subfamily Phyxelidinae (Araneae, Amaurobiidae). Bulletin of the American Museum of Natural History, 196, 1- 206.',
#     'Helsdingen, P.J. van (2014): Araneae.In: Fauna Europaea. Database European spiders and their distribution. Taxonomy. Version 2013.1. www.faunaeur.org [accessed on 11 January 2015]',
#     'Huber, B. A. (2002): Functional morphology of the genitalia in the spider Spermophora senoculata (Pholcidae, Araneae). Zoologischer Anzeiger, 241, 105-116.',
#     'Kovblyuk, M. M., Marusik, Y. M., Ponomarev, A. V., Gnelitsa, V. A., & Nadolny, A. A. (2011): Spiders (Arachnida: Aranei) of Abkhazia. Arthropoda Selecta, 20, 21-56.',
#     'Kovblyuk, M. M., & Nadolny, A. A. (2009): The spider genus Trachelas L. Koch, 1872 in Crimea and Caucasus with the description of Paratrachelas gen. n. (Aranei: Corinnidae). Arthropoda Selecta, 18, 35-46.',
#     'Kraus, O. (1967): Zur Spinnenfauna Deutschlands, II. Mysmena jobi n. sp., eine Symphytognathide in Mitteleuropa (Arachnida: Araneae: Symphytognathidae). Senckenbergiana biologica, 48, 387-399.',
#     'Kronestedt, T. (1997): First record of Aulonia kratochvili (Araneae, Lycosidae) from Europe. Arachnologische Mitteilungen, 14, 77-80.',
#     'Levy, G. (2007): Calommata (Atypidae) and new spider species (Araneae) from Israel. Zootaxa, 1551, 1-30.',
#     'Logunov, D. V., & Kronestedt, T. (2003): A review of the genus Talavera Peckham and Peckham, 1909 (Araneae, Salticidae). Journal of Natural History, 37, 1091-1154.',
#     'Logunov, D. V., & Marusik, Y. M. (2000): Miscellaneous notes on Palaearctic Salticidae (Arachnida: Aranei). Arthropoda Selecta, 8, 263-292.',
#     'Marusik, Y. M., Kunt, K. B., & Danisman, T. (2009): Spiders (Aranei) new to the fauna of Turkey. 2. New species records of Theridiidae. Arthropoda Selecta, 18: 69-75.',
#     'Marusik, Y. M., Ozkutuk, R. S., Kunt, K. B., & Kaya, R. S. (2011): Spiders (Araneae) new to the fauna of Turkey. 8. New records of Hahniidae and Dictynidae. Anadolu University Journal of Science and Technology -C, 1, 161-170.',
#     'Metzner, H. (1999): Die Springspinnen (Araneae, Salticidae) Griechenlands. Andrias, 14, 1-279.',
#     'Mikhailov, K. G. (2013): The spiders (Arachnida: Aranei) of Russia and adjacent countries: a non-annotated checklist. Arthropoda Selecta. Supplement, 3.',
#     'Otto, S. (2014): Caucasian Spiders. A faunistic database on the spiders of the Caucasus. Version 1.4. Internet: http://caucasus-spiders.info [accessed 11 January 2015].',
#     'Ozkutuk, R. S., Marusik, Y. M., Kunt, K. B., & Danisman, T. (2011): New records for spider (Araneae) fauna of Turkey: Paratrachelas maculatus (Thorell, 1875) [Corinnidae], Sintula retroversus (O. P.-Cambridge, 1875) [Linyphiidae] and Agroeca proxima (O. P.-Cambridge, 1871) [Liocranidae]. Biological Diversity Conservation, 4, 224-232.',
#     "Perez, P. J. A., & Blasco, F. A. (1986): Nota sobre los Prodidominae (Araneae: Gnaphosidae) de la Peninsula Iberica. Memoires de la Societe Royal Belge d'Entomologie, 33, 155-164.",
#     'Platnick, N. I., & Baehr, B. (2006): A revision of the Australasian ground spiders of the family Prodidomidae (Araneae, Gnaphosoidea). Bulletin of the American Museum of Natural History, 298, 1-287.',
#     'Platnick, N. (2014): The World Spider Catalog, Version 15. http://research.amnh.org/iz/spiders/catalog/INTRO1.html [accessed on 11 January 2015].',
#     'Proszynski, J. (1998): Description of new species of Phlegra (Araneae: Salticidae) from Israel. Israel Journal of Zoology, 44, 159-185.',
#     'Proszyski, J. (2000): On mostly new species of Salticidae (Aranei) from Levant. Arthropoda Selecta, 8, 231-262.',
#     'Proszyski, J. (2003): Salticidae (Araneae) of the Levant. Annales Zoologici (Warsaw), 53, 1-180.',
#     'Roberts, M. J. (1998): Spinnengids. Tirion, Baarn (the Netherlands).',
#     'Roewer, C. F. (1955): Katalog der Araneae von 1758 bis 1940, bzw. 1954. Bruxelles, 2, 1-1751.',
#     'Saaristo, M. I. (2007): The oonopid spiders (Aranei: Oonopidae) of Israel. Arthropoda Selecta, 15, 119-140.',
#     "Simon, E. (1897): Arachnides recueillis par M. M. Maindron a Mascate, en octobre 1896. Bulletin du Museum National d'Histoire Naturelle de Paris, 1897, 95-98.",
#     'Strand, E. (1913): Erste Mitteilung uber Spinnen aus Palastina, gesammelt von Herrn Dr J. Aharoni. Archiv fur Naturgeschichte, 79(A10), 147-162.',
#     'Thaler, K., & Knoflach, B. (1998): Phyxelida anatolica Griswold, new to Cyprus (Arachnida Araneae: Amaurobiidae, Phyxelidinae). Bulletin of the British Arachnological Society, 11, 36-40.',
#     'Thaler, K., van Harten, A., & Knoflach, B. (2004): Pirate spiders of the genus Ero C.L. Koch from southern Europe, Yemen, and Ivory Coast, with two new species (Arachnida, Araneae, Mimetidae). Denisia, 13, 359-368.',
# ...
#    'doi': '10.5281/zenodo.580617',
#    'journal': {'issue': '4 RACEEE',
#     'pages': '8-14',
#     'title': 'IMAGE DENOISING USING WAVELET AND SHEARLET TRANSFORM',
#     'volume': '5'},
#    'keywords': ['Types of Noise; Denoising Filters; Histogram; Wavelet Transform; Shearlet Transform; MATLAB 2016b.'],
#    'license': {'id': 'CC-BY-4.0'},
#    'publication_date': '2017-06-01',
#    'related_identifiers': [{'identifier': '10.5281/zenodo.599071',
#      'relation': 'isPartOf',
#      'scheme': 'doi'}],
#    'relations': {'version': [{'count': 1,
#       'index': 0,
#       'is_last': True,
#       'last_child': {'pid_type': 'recid', 'pid_value': '580617'},
#       'parent': {'pid_type': 'recid', 'pid_value': '599071'}}]},
#    'resource_type': {'subtype': 'article',
#     'title': 'Journal article',
#     'type': 'publication'},
#    'title': 'IMAGE DENOISING USING WAVELET AND SHEARLET TRANSFORM'},
#   'owners': [24679],
#   'revision': 2,
#   'updated': '2017-06-14T13:50:54.407880+00:00'},
#  {'conceptdoi': '10.5281/zenodo.808270',
#   'conceptrecid': '808270',
#   'created': '2017-06-14T11:41:08.438989+00:00',
#   'doi': '10.5281/zenodo.808271',
#   'id': 808271,
#   'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.808271.svg',
#    'bucket': 'https://zenodo.org/api/files/9bc0718e-d9a6-46c4-bfad-4eccb5a9c0d4',
#    'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.808270.svg',
#    'conceptdoi': 'https://doi.org/10.5281/zenodo.808270',
#    'doi': 'https://doi.org/10.5281/zenodo.808271',
#    'html': 'https://zenodo.org/record/808271',
#    'latest': 'https://zenodo.org/api/records/808271',
#    'latest_html': 'https://zenodo.org/record/808271',
#    'self': 'https://zenodo.org/api/records/808271'},
#   'metadata': {'access_right': 'open',
#    'access_right_category': 'success',
#    'communities': [{'id': 'ioda'}],
#    'creators': [{'affiliation': 'Aachen University', 'name': 'Dastouri, Z'},
#     {'affiliation': 'Aachen University', 'name': 'Gezgin, S.M.'},
#     {'affiliation': 'Aachen University', 'name': 'Naumann, U.'}],
#    'description': '<p>Adjoint based calculation of sensitivities pertaining to a Computational Fluid Dynamics (CFD) Solver has proven to be a vital tool in tackling large scale problems often found in industrial applications. There are two basic approaches for applying Algorithmic Differentiation (AD) to a CFD solver, namely, Operator Overloading and Source Transformation.<br>\nUnfortunately, in both cases, it is still necessary to invest a significant amount of manual coding in order to get to an application that performs acceptably in terms of memory consumption and runtime. In this paper reverse mode of AD has been applied to an unstructured pressure based steady Navier-Stokes solver. We explore the feasibility of combining both kinds of AD approaches to show where and how the advantages of each method can be exploited in order to reach a suitable compromise between performance, simplicity and efficiency. Additionally,we propose a methodology to automate the implementation of an adjoint software in order to minimize work the developer must carry out to produce the desired derivative. We investigate the effectiveness of this approach for relevant flow test cases.</p>',
#    'doi': '10.5281/zenodo.808271',
#    'grants': [{'acronym': 'ABOUTFLOW',
#      'code': '317006',
#      'funder': {'acronyms': ['EC'],
#       'doi': '10.13039/501100000780',
#       'links': {'self': 'https://zenodo.org/api/funders/10.13039/501100000780'},
#       'name': 'European Commission'},
#      'links': {'self': 'https://zenodo.org/api/grants/10.13039/501100000780::317006'},
#      'program': 'FP7',
#      'title': 'Adjoint-based optimisation of industrial and unsteady flows'}],
#    'keywords': ['Algorithmic Differentiation',
#     'Computational Fluid Dynamics',
#     'Operator Overloading',
#     'Source Transformation'],
#    'license': {'id': 'CC-BY-4.0'},
#    'meeting': {'acronym': 'ECCOMAS',
#     'dates': '5010 June 2016',
#     'place': 'Greece'},
#    'publication_date': '2016-06-06',
#    'related_identifiers': [{'identifier': '10.5281/zenodo.808270',
#      'relation': 'isPartOf',
#      'scheme': 'doi'}],
#    'relations': {'version': [{'count': 1,
#       'index': 0,
#       'is_last': True,
#       'last_child': {'pid_type': 'recid', 'pid_value': '808271'},
#       'parent': {'pid_type': 'recid', 'pid_value': '808270'}}]},
#    'resource_type': {'title': 'Presentation', 'type': 'presentation'},
#    'title': 'A Mixed Operator Overloading and Source Transformation Approach for Adjoint CFD Computation'},
#   'owners': [25072],
#   'revision': 3,
#   'updated': '2017-06-14T13:50:54.404998+00:00'},
#  {'conceptdoi': '10.5281/zenodo.604639',
#   'conceptrecid': '604639',
#   'created': '2017-06-14T11:21:03.719502+00:00',
#   'doi': '10.5281/zenodo.580621',
#   'id': 580621,
#   'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.580621.svg',
#    'bucket': 'https://zenodo.org/api/files/b88a3e64-0fd6-44a2-98a6-7c585417ff05',
#    'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.604639.svg',
#    'conceptdoi': 'https://doi.org/10.5281/zenodo.604639',
#    'doi': 'https://doi.org/10.5281/zenodo.580621',
#    'html': 'https://zenodo.org/record/580621',
#    'latest': 'https://zenodo.org/api/records/580621',
#    'latest_html': 'https://zenodo.org/record/580621',
#    'self': 'https://zenodo.org/api/records/580621'},
#   'metadata': {'access_right': 'open',
#    'access_right_category': 'success',
#    'creators': [{'affiliation': 'Department of Electrical and Electronics Engineering, School of Engineering and Technology, Jain University, Karnataka- 562112, India',
#      'name': 'Nagendra K'},
#     {'affiliation': 'Department of Electrical and Electronics Engineering, School of Engineering and Technology, Jain University, Karnataka- 562112, India',
#      'name': 'Chandan Kumar'},
#     {'affiliation': 'Department of Electrical and Electronics Engineering, School of Engineering and Technology, Jain University, Karnataka- 562112, India',
#      'name': 'Gowri P N'},
#     {'affiliation': 'Department of Electrical and Electronics Engineering, School of Engineering and Technology, Jain University, Karnataka- 562112, India',
#      'name': 'Prathika M S'},
#     {'affiliation': 'Department of Electrical and Electronics Engineering, School of Engineering and Technology, Jain University, Karnataka- 562112, India',
#      'name': 'Kavyashree D'}],
#    'description': '<p>The objective of this paper is to model and simulate the grid connected wind mill using MATLAB/SIMULINK. Wind energy is a renewable energy and its running cost negligible as wind is freely available. The non -renewable energy are being exhausted and therefore there is a need to switch to renewable sources of energy. For utilizing wind energy, wind turbines are used and different parameters like, shape and size of the blades, wind speed, generator characteristics etc. are considered in calculating the efficiency of the turbine. This paper deals with the performance study of the output from the permanent magnet synchronous generator PMSG coupled with the wind turbine. In this case performance test is conducted with two variable speeds and the reactive power, active power, voltage and current waveforms of the inverter is plotted using SIMULINK.</p>',
#    'doi': '10.5281/zenodo.580621',
#    'journal': {'issue': '4 RACEEE',
#     'pages': '29-35',
#     'title': 'MODELING AND SIMULATION OF WIND TURBINE COUPLED WITH A PERMANENT MAGNET SYNCHRONOUS GENERATOR UNDER GRID CONNECTED SYSTEM',
#     'volume': '5'},
#    'keywords': [': PQ Control; Voltage Source Inverter (VSI); Boost Converter; Permanent Magnet Synchronous Generator (PMSG).'],
#    'license': {'id': 'CC-BY-4.0'},
#    'publication_date': '2017-06-01',
#    'related_identifiers': [{'identifier': '10.5281/zenodo.604639',
#      'relation': 'isPartOf',
#      'scheme': 'doi'}],
#    'relations': {'version': [{'count': 1,
#       'index': 0,
#       'is_last': True,
#       'last_child': {'pid_type': 'recid', 'pid_value': '580621'},
#       'parent': {'pid_type': 'recid', 'pid_value': '604639'}}]},
#    'resource_type': {'subtype': 'article',
#     'title': 'Journal article',
#     'type': 'publication'},
#    'title': 'MODELING AND SIMULATION OF WIND TURBINE COUPLED WITH A PERMANENT MAGNET SYNCHRONOUS GENERATOR UNDER GRID CONNECTED SYSTEM'},
#   'owners': [24679],
#   'revision': 2,
#   'updated': '2017-06-14T13:50:54.411169+00:00'},
#  {'conceptdoi': '10.5281/zenodo.599842',
#   'conceptrecid': '599842',
#   'created': '2017-06-14T12:20:42.462360+00:00',
#   'doi': '10.5281/zenodo.580631',
#   'id': 580631,
#   'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.580631.svg',
#    'bucket': 'https://zenodo.org/api/files/e6985f79-8ce0-4dd0-8fb0-badf9741be75',
#    'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.599842.svg',
#    'conceptdoi': 'https://doi.org/10.5281/zenodo.599842',
#    'doi': 'https://doi.org/10.5281/zenodo.580631',
#    'html': 'https://zenodo.org/record/580631',
#    'latest': 'https://zenodo.org/api/records/580631',
#    'latest_html': 'https://zenodo.org/record/580631',
#    'self': 'https://zenodo.org/api/records/580631'},
#   'metadata': {'access_right': 'open',
#    'access_right_category': 'success',
#    'creators': [{'affiliation': 'Department of Electronics and Communication Engineering, S.I.T, Tumakuru, India',
#      'name': 'Purushottama T L'},
#     {'affiliation': 'Department of Electronics and Communication Engineering, S.I.T, Tumakuru, India',
#      'name': 'Kishore C'}],
#    'description': '<p>Diabetic Retinopathy (DR) is progressive dysfunction of the retinal blood vessels caused by chronic hyperglycemia which can be a complication of diabetes type 1 or diabetes type 2. Initially, DR is asymptomatic, if not treated though it can cause low vision and blindness. Diabetic retinopathy is responsible for 1.8 million of the 37 million cases of blindness throughout the world. So the early detection of Diabetic retinopathy through proper screening is essential. The paper presents a Diabetic Retinopathy Screening System which can be used as a primary diagnosis tool by ophthalmologists in the screening process to detect symptoms of Diabetic Retinopathy. The system uses the anatomical structures such as blood vessels, exudates and microaneurysms in retinal images. The retinal images are segmented and classified as normal or DR affected images by extracting features from segmented images and the Gray Level Cooccurrence Matrix (GLCM). The classifier used is Support Vector Machine (SVM) which gives a better accuracy. The system is implemented and tested in MATLAB and LabView for the standard database and need to be optimized for real time screening of images. LabView creates distributable .EXE files and .DLL files which can be downloaded into the FPGA/DSP processor. Hardware implementation on LabView FPGA presents a small learning curve which drastically reduces development time and eliminates the need for custom hardware design</p>',
#    'doi': '10.5281/zenodo.580631',
#    'journal': {'issue': '4 RACEEE',
#     'pages': '92-104',
#     'title': 'DIAGNOSIS OF DIABETIC RETINOPATHY THROUGH SCREENING OF RETINAL IMAGES',
#     'volume': '5'},
#    'keywords': ['Diabetic Retinopathy (DR); Blood Vessels; Exudates; Microaneurysms (MA); Morphological Processing; Grey Level Co-Occurrence Matrix (GLCM); Support Vector Machine (SVM).'],
#    'license': {'id': 'CC-BY-4.0'},
#    'publication_date': '2017-06-01',
#    'related_identifiers': [{'identifier': '10.5281/zenodo.599842',
#      'relation': 'isPartOf',
#      'scheme': 'doi'}],
#    'relations': {'version': [{'count': 1,
#       'index': 0,
#       'is_last': True,
#       'last_child': {'pid_type': 'recid', 'pid_value': '580631'},
#       'parent': {'pid_type': 'recid', 'pid_value': '599842'}}]},
#    'resource_type': {'subtype': 'article',
#     'title': 'Journal article',
#     'type': 'publication'},
#    'title': 'DIAGNOSIS OF DIABETIC RETINOPATHY THROUGH SCREENING OF RETINAL IMAGES'},
#   'owners': [24679],
#   'revision': 2,
#   'updated': '2017-06-14T13:50:54.411890+00:00'},
#  {'conceptdoi': '10.5281/zenodo.807794',
#   'conceptrecid': '807794',
#   'created': '2017-06-14T06:43:43.285261+00:00',
#   'doi': '10.5281/zenodo.807795',
#   'id': 807795,
#   'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807795.svg',
#    'bucket': 'https://zenodo.org/api/files/a533b2f2-b774-4c11-b100-79f02175a517',
#    'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807794.svg',
#    'conceptdoi': 'https://doi.org/10.5281/zenodo.807794',
#    'doi': 'https://doi.org/10.5281/zenodo.807795',
#    'html': 'https://zenodo.org/record/807795',
#    'latest': 'https://zenodo.org/api/records/807795',
#    'latest_html': 'https://zenodo.org/record/807795',
#    'self': 'https://zenodo.org/api/records/807795'},
#   'metadata': {'access_right': 'open',
#    'access_right_category': 'success',
#    'communities': [{'id': 'prace'}],
#    'contributors': [{'affiliation': 'EPCC, The University of Edinburgh, James Clerk Maxwell Building, Mayfield Road, Edinburgh, EH9 3JZ, UK',
#      'name': 'Ruyman Reyes',
#      'type': 'Other'}],
#    'creators': [{'affiliation': 'EPCC, The University of Edinburgh, James Clerk Maxwell Building, Mayfield Road, Edinburgh, EH9 3JZ, UK',
#      'name': 'Iain Bethune'}],
#    'description': '<p>This report describes the results of a PRACE Preparatory Access Type Cb project to optimise the implementation<br>\nof Møller-Plesset second order perturbation theory (MP2) in CP2K, to allow it to be used efficiently on the<br>\nPRACE Research Infrastructure. The work consisted of three stages: firstly serial optimisation of several key<br>\ncomputational kernels; secondly, OpenMP implementation of parallel 3D Fourier Transform to support mixedmode<br>\nMPI/OpenMP use of CP2K; and thirdly - benchmarking the performance gains achieved by new code on<br>\nHERMIT for a test case representative of proposed production simulations. Consistent speedups of 8% were<br>\nachieved in the integration kernel routines as a result of the serial optimisation. When using 8 OpenMP threads<br>\nper MPI process, speedups of up to 10x for the 3D FFT were achieved, and for some combinations of MPI<br>\nprocesses and OpenMP threads, overall speedups of 66% for the whole code were measured. As a result of this<br>\nwork, a proposal for full PRACE Project Access has been submitted.</p>',
#    'doi': '10.5281/zenodo.807795',
#    'grants': [{'acronym': 'PRACE-2IP',
#      'code': '283493',
#      'funder': {'acronyms': ['EC'],
#       'doi': '10.13039/501100000780',
#       'links': {'self': 'https://zenodo.org/api/funders/10.13039/501100000780'},
#       'name': 'European Commission'},
#      'links': {'self': 'https://zenodo.org/api/grants/10.13039/501100000780::283493'},
#      'program': 'FP7',
#      'title': 'PRACE - Second Implementation Phase Project'}],
#    'keywords': ['Møller-Plesset, CP2K, MPI/OpenMP, HERMIT'],
#    'license': {'id': 'CC-BY-4.0'},
#    'publication_date': '2013-02-28',
#    'related_identifiers': [{'identifier': '10.5281/zenodo.807794',
#      'relation': 'isPartOf',
#      'scheme': 'doi'}],
#    'relations': {'version': [{'count': 1,
#       'index': 0,
#       'is_last': True,
#       'last_child': {'pid_type': 'recid', 'pid_value': '807795'},
#       'parent': {'pid_type': 'recid', 'pid_value': '807794'}}]},
#    'resource_type': {'subtype': 'workingpaper',
#     'title': 'Working paper',
#     'type': 'publication'},
#    'title': 'High Performance MP2 for Condensed Phase Simulations'},
#   'owners': [32622],
#   'revision': 2,
#   'updated': '2017-06-14T13:50:54.418028+00:00'}]

# %%
print(url)
# Out:
# https://zenodo.org/api/records?page=1&size=100&q=created:%5B2017-06-14%20TO%202017-06-15%5D

# %%
headers = {"Content-Type": "application/json"}
resp = requests.get(url, headers=headers)

# %%
resp.status_code
# Out:
# 200

# %%
resp.json()['links']
# Out:
# {'next': 'https://zenodo.org/api/records/?sort=bestmatch&q=created%3A%5B2017-06-14+TO+2017-06-15%5D&page=2&size=100',
#  'self': 'https://zenodo.org/api/records/?sort=bestmatch&q=created%3A%5B2017-06-14+TO+2017-06-15%5D&page=1&size=100'}

# %%
resp.json()['hits']
# Out:
# {'hits': [{'conceptdoi': '10.5281/zenodo.807826',
#    'conceptrecid': '807826',
#    'created': '2017-06-14T07:13:55.748781+00:00',
#    'doi': '10.5281/zenodo.807827',
#    'id': 807827,
#    'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807827.svg',
#     'bucket': 'https://zenodo.org/api/files/c12e356e-9d94-46bc-929e-7d42521dbac9',
#     'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807826.svg',
#     'conceptdoi': 'https://doi.org/10.5281/zenodo.807826',
#     'doi': 'https://doi.org/10.5281/zenodo.807827',
#     'html': 'https://zenodo.org/record/807827',
#     'latest': 'https://zenodo.org/api/records/807827',
#     'latest_html': 'https://zenodo.org/record/807827',
#     'self': 'https://zenodo.org/api/records/807827'},
#    'metadata': {'access_right': 'open',
#     'access_right_category': 'success',
#     'communities': [{'id': 'biosyslit'}],
#     'creators': [{'name': 'Doğan, Sibel'},
#      {'name': 'Doğan, Salih'},
#      {'name': 'Erman, Orhan'}],
#     'description': 'FIGURE 4. Stigmaeus communis sp. nov. (Male) A. Dorsal view of idiosoma, B. Ventral view of idiosoma.',
#     'doi': '10.5281/zenodo.807827',
#     'keywords': ['Biodiversity',
#      'Taxonomy',
#      'Animalia',
#      'Arthropoda',
#      'Arachnida',
#      'Prostigmata',
#      'Stigmaeidae',
#      'Stigmaeus'],
#     'license': {'id': 'notspecified'},
#     'publication_date': '2017-12-31',
#     'related_identifiers': [{'identifier': 'http://treatment.plazi.org/id/03F087A3FFE18850FF04AE53FF7F88CA',
#       'relation': 'isCitedBy',
#       'scheme': 'url'},
#      {'identifier': '10.11646/zootaxa.4276.4.1',
#       'relation': 'isPartOf',
#       'scheme': 'doi'},
#      {'identifier': 'urn:lsid:plazi.org:pub:FFC9FFDBFFE08855FF93AC31FFA08B04',
#       'relation': 'isPartOf',
#       'scheme': 'lsid'},
#      {'identifier': 'https://zenodo.org/record/807819',
#       'relation': 'isPartOf',
#       'scheme': 'url'},
#      {'identifier': '10.5281/zenodo.807826',
#       'relation': 'isPartOf',
#       'scheme': 'doi'}],
#     'relations': {'version': [{'count': 1,
#        'index': 0,
#        'is_last': True,
#        'last_child': {'pid_type': 'recid', 'pid_value': '807827'},
#        'parent': {'pid_type': 'recid', 'pid_value': '807826'}}]},
#     'resource_type': {'subtype': 'figure', 'title': 'Figure', 'type': 'image'},
#     'title': 'FIGURE 4 in Description of five new species of the genus Stigmaeus Koch (Acari: Raphignathoidea: Stigmaeidae) from Turkey'},
#    'owners': [1161],
#    'revision': 1,
#    'updated': '2017-06-14T07:13:55.940478+00:00'},
#   {'conceptdoi': '10.5281/zenodo.807820',
#    'conceptrecid': '807820',
#    'created': '2017-06-14T07:13:46.738541+00:00',
#    'doi': '10.5281/zenodo.807821',
#    'id': 807821,
#    'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807821.svg',
#     'bucket': 'https://zenodo.org/api/files/50565cf0-2404-4efe-819b-2cceeb734889',
#     'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807820.svg',
#     'conceptdoi': 'https://doi.org/10.5281/zenodo.807820',
#     'doi': 'https://doi.org/10.5281/zenodo.807821',
#     'html': 'https://zenodo.org/record/807821',
#     'latest': 'https://zenodo.org/api/records/807821',
#     'latest_html': 'https://zenodo.org/record/807821',
#     'self': 'https://zenodo.org/api/records/807821'},
#    'metadata': {'access_right': 'open',
#     'access_right_category': 'success',
#     'communities': [{'id': 'biosyslit'}],
#     'creators': [{'name': 'Doğan, Sibel'},
#      {'name': 'Doğan, Salih'},
#      {'name': 'Erman, Orhan'}],
#     'description': 'FIGURE 1. Stigmaeus communis sp. nov. (Female) A Dorsal view of idiosoma, B. Ventral view of idiosoma.',
#     'doi': '10.5281/zenodo.807821',
#     'keywords': ['Biodiversity',
#      'Taxonomy',
#      'Animalia',
#      'Arthropoda',
#      'Arachnida',
#      'Prostigmata',
#      'Stigmaeidae',
#      'Stigmaeus'],
#     'license': {'id': 'notspecified'},
#     'publication_date': '2017-12-31',
#     'related_identifiers': [{'identifier': 'http://treatment.plazi.org/id/03F087A3FFE18850FF04AE53FF7F88CA',
#       'relation': 'isCitedBy',
#       'scheme': 'url'},
#      {'identifier': '10.11646/zootaxa.4276.4.1',
#       'relation': 'isPartOf',
#       'scheme': 'doi'},
#      {'identifier': 'urn:lsid:plazi.org:pub:FFC9FFDBFFE08855FF93AC31FFA08B04',
#       'relation': 'isPartOf',
#       'scheme': 'lsid'},
#      {'identifier': 'https://zenodo.org/record/807819',
#       'relation': 'isPartOf',
#       'scheme': 'url'},
#      {'identifier': '10.5281/zenodo.807820',
#       'relation': 'isPartOf',
#       'scheme': 'doi'}],
#     'relations': {'version': [{'count': 1,
#        'index': 0,
#        'is_last': True,
#        'last_child': {'pid_type': 'recid', 'pid_value': '807821'},
#        'parent': {'pid_type': 'recid', 'pid_value': '807820'}}]},
#     'resource_type': {'subtype': 'figure', 'title': 'Figure', 'type': 'image'},
#     'title': 'FIGURE 1 in Description of five new species of the genus Stigmaeus Koch (Acari: Raphignathoidea: Stigmaeidae) from Turkey'},
#    'owners': [1161],
#    'revision': 1,
#    'updated': '2017-06-14T07:13:46.932388+00:00'},
#   {'conceptdoi': '10.5281/zenodo.808003',
#    'conceptrecid': '808003',
#    'created': '2017-06-14T08:08:26.747617+00:00',
#    'doi': '10.5281/zenodo.808004',
#    'id': 808004,
#    'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.808004.svg',
#     'bucket': 'https://zenodo.org/api/files/e9c92b1b-d92b-4726-8d89-93f0839b96ce',
#     'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.808003.svg',
#     'conceptdoi': 'https://doi.org/10.5281/zenodo.808003',
#     'doi': 'https://doi.org/10.5281/zenodo.808004',
#     'html': 'https://zenodo.org/record/808004',
#     'latest': 'https://zenodo.org/api/records/808004',
#     'latest_html': 'https://zenodo.org/record/808004',
#     'self': 'https://zenodo.org/api/records/808004'},
#    'metadata': {'access_conditions': '<p>Visionierung auf Anfrage</p>',
#     'access_right': 'restricted',
#     'access_right_category': 'danger',
#     'communities': [{'id': 'buchjahr'}],
#     'creators': [{'name': 'Keller, Judith'}],
#     'description': '<p>Filmische Buchbesprechung zum Werk</p>\n\n<p>Zwicky, Dieter. (2016). <em>Hihi - Mein argentinischer Vater : Erzählung</em> (1. Auflage ed.). Wädenswil: Pudelundpinscher.</p>',
#     'doi': '10.5281/zenodo.808004',
#     'keywords': ['Schweizer Buchjahr',
#      'Buchjahr 2016',
#      'Buchbesprechung',
#      'Videorezension'],
#     'publication_date': '2016-09-30',
#     'related_identifiers': [{'identifier': '10.5281/zenodo.808003',
#       'relation': 'isPartOf',
#       'scheme': 'doi'}],
#     'relations': {'version': [{'count': 1,
#        'index': 0,
#        'is_last': True,
#        'last_child': {'pid_type': 'recid', 'pid_value': '808004'},
#        'parent': {'pid_type': 'recid', 'pid_value': '808003'}}]},
#     'resource_type': {'title': 'Video/Audio', 'type': 'video'},
#     'title': 'Hihi - mein argentinischer Vater / Dieter Zwicky [Viderezension]'},
#    'owners': [24712],
#    'revision': 2,
#    'updated': '2017-06-14T08:42:47.246921+00:00'},
#   {'conceptdoi': '10.5281/zenodo.807762',
#    'conceptrecid': '807762',
#    'created': '2017-06-14T03:35:46.314390+00:00',
#    'doi': '10.5281/zenodo.807763',
#    'id': 807763,
#    'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807763.svg',
#     'bucket': 'https://zenodo.org/api/files/a9c99371-ca49-463b-b279-7c7559c5ee9d',
#     'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807762.svg',
#     'conceptdoi': 'https://doi.org/10.5281/zenodo.807762',
#     'doi': 'https://doi.org/10.5281/zenodo.807763',
#     'html': 'https://zenodo.org/record/807763',
#     'latest': 'https://zenodo.org/api/records/807763',
#     'latest_html': 'https://zenodo.org/record/807763',
#     'self': 'https://zenodo.org/api/records/807763'},
#    'metadata': {'access_right': 'open',
#     'access_right_category': 'success',
#     'creators': [{'affiliation': 'McMaster University', 'name': 'icbicket'}],
#     'description': '<p>Initial release of Python code for analyzing spectrum images collected with electron energy loss spectroscopy and cathodoluminescence. The focus is on plasmonics applications (low-loss EELS), providing navigation of 3D datasets, Richardson-Lucy deconvolution, and aligning spectra and images.</p>',
#     'doi': '10.5281/zenodo.807763',
#     'license': {'id': 'other-open'},
#     'publication_date': '2017-06-14',
#     'related_identifiers': [{'identifier': 'https://github.com/icbicket/DataAnalysis/tree/v1.0.0',
#       'relation': 'isSupplementTo',
#       'scheme': 'url'},
#      {'identifier': '10.5281/zenodo.807762',
#       'relation': 'isPartOf',
#       'scheme': 'doi'}],
#     'relations': {'version': [{'count': 1,
#        'index': 0,
#        'is_last': True,
#        'last_child': {'pid_type': 'recid', 'pid_value': '807763'},
#        'parent': {'pid_type': 'recid', 'pid_value': '807762'}}]},
#     'resource_type': {'title': 'Software', 'type': 'software'},
#     'title': 'icbicket/DataAnalysis: SpectrumImagingAnalysisPy'},
#    'owners': [32726],
#    'revision': 2,
#    'updated': '2017-06-14T03:49:08.420784+00:00'},
#   {'conceptdoi': '10.5281/zenodo.807908',
#    'conceptrecid': '807908',
#    'created': '2017-06-14T07:41:39.255322+00:00',
#    'doi': '10.5281/zenodo.807909',
#    'id': 807909,
#    'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807909.svg',
#     'bucket': 'https://zenodo.org/api/files/5a3a17cb-5fd2-409e-a9c0-c47b1dc773fc',
#     'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807908.svg',
#     'conceptdoi': 'https://doi.org/10.5281/zenodo.807908',
#     'doi': 'https://doi.org/10.5281/zenodo.807909',
#     'html': 'https://zenodo.org/record/807909',
#     'latest': 'https://zenodo.org/api/records/807909',
#     'latest_html': 'https://zenodo.org/record/807909',
#     'self': 'https://zenodo.org/api/records/807909'},
#    'metadata': {'access_right': 'open',
#     'access_right_category': 'success',
#     'communities': [{'id': 'biosyslit'}],
#     'creators': [{'name': 'Wilke, Tanja'},
#      {'name': 'Ahlrichs, Wilko H.'},
#      {'name': 'Bininda-Emonds, Olaf R. P.'}],
#     'description': 'FIGURE 4. SEM photographs of the trophi of A – E S. tremula and F – J S. tremuloida (A, F, ventral; B, G dorsal; C, H lateral with the ventral rami pointing upwards; D, I unci, apical view with the ventral side of the trophus pointing upwards; E, J unci, frontal hooks and triangular platelet, latero-apical detail with the ventral side of the trophus pointing upwards). ca, cauda; cl, clava; clt, toothlike clava-lamella; dfh, dorsal frontal hook; hyp, hypopharynx; fu, fulcrum; ra, ramus; rdr, ramus distal ridge; rir, ramus inner ridge; rmr, ramus median ridge; tp, triangular platelet; un, uncus; and vfh, ventral frontal hook.',
#     'doi': '10.5281/zenodo.807909',
#     'keywords': ['Biodiversity',
#      'Taxonomy',
#      'Animalia',
#      'Rotifera',
#      'Eurotatoria',
#      'Ploima',
#      'Synchaetidae',
#      'Synchaeta'],
#     'license': {'id': 'notspecified'},
#     'publication_date': '2017-12-31',
#     'related_identifiers': [{'identifier': 'http://treatment.plazi.org/id/4606AF6BCE475C436CAAFDEBFC9BFE79',
#       'relation': 'isCitedBy',
#       'scheme': 'url'},
#      {'identifier': '10.11646/zootaxa.4276.4.3',
#       'relation': 'isPartOf',
#       'scheme': 'doi'},
#      {'identifier': 'urn:lsid:plazi.org:pub:BA3FD713CE4E5C486C3DFFCFFF89FFA9',
#       'relation': 'isPartOf',
#       'scheme': 'lsid'},
#      {'identifier': 'https://zenodo.org/record/807901',
#       'relation': 'isPartOf',
#       'scheme': 'url'},
#      {'identifier': '10.5281/zenodo.807908',
#       'relation': 'isPartOf',
#       'scheme': 'doi'}],
#     'relations': {'version': [{'count': 1,
#        'index': 0,
#        'is_last': True,
#        'last_child': {'pid_type': 'recid', 'pid_value': '807909'},
#        'parent': {'pid_type': 'recid', 'pid_value': '807908'}}]},
#     'resource_type': {'subtype': 'figure', 'title': 'Figure', 'type': 'image'},
#     'title': 'FIGURE 4 in A comprehensive and integrative re-description of Synchaeta tremula (Müller, 1786) and the newly rediscovered Synchaeta tremuloida Pourriot, 1965 (Rotifera: Synchaetidae)'},
#    'owners': [1161],
#    'revision': 1,
#    'updated': '2017-06-14T07:41:39.481980+00:00'},
#   {'conceptdoi': '10.5281/zenodo.807904',
#    'conceptrecid': '807904',
#    'created': '2017-06-14T07:41:32.004686+00:00',
#    'doi': '10.5281/zenodo.807905',
#    'id': 807905,
#    'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807905.svg',
#     'bucket': 'https://zenodo.org/api/files/e37f170c-2233-4633-ae1b-f7e55962bda8',
#     'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807904.svg',
#     'conceptdoi': 'https://doi.org/10.5281/zenodo.807904',
#     'doi': 'https://doi.org/10.5281/zenodo.807905',
#     'html': 'https://zenodo.org/record/807905',
#     'latest': 'https://zenodo.org/api/records/807905',
#     'latest_html': 'https://zenodo.org/record/807905',
#     'self': 'https://zenodo.org/api/records/807905'},
#    'metadata': {'access_right': 'open',
#     'access_right_category': 'success',
#     'communities': [{'id': 'biosyslit'}],
#     'creators': [{'name': 'Wilke, Tanja'},
#      {'name': 'Ahlrichs, Wilko H.'},
#      {'name': 'Bininda-Emonds, Olaf R. P.'}],
#     'description': 'FIGURE 2. SEM photographs of the habitus of A – C S. tremula and D – F S. tremuloida (A, D, dorsally; B, E, apically; C, F, anal-pseudosegment and foot with toes, lateral view). Scale bars: 10 µm. aps, anal-pseudosegment; ar, apical receptor; asc, ampulla shaped cilia; au, auricle; da, dorsal antenna; dcf, dorsal ciliary field; dlcf, dorsolateral ciliary field; dst, dorsal stylus; gm, gland meatus; la, lateral antennae; lcf, lateral ciliary field; lst, lateral stylus; mr 1 – 3, mouth receptors; and vlcf, ventrolateral ciliary field.',
#     'doi': '10.5281/zenodo.807905',
#     'keywords': ['Biodiversity',
#      'Taxonomy',
#      'Animalia',
#      'Rotifera',
#      'Eurotatoria',
#      'Ploima',
#      'Synchaetidae',
#      'Synchaeta'],
#     'license': {'id': 'notspecified'},
#     'publication_date': '2017-12-31',
#     'related_identifiers': [{'identifier': 'http://treatment.plazi.org/id/4606AF6BCE4C5C416CAAF94AFE58FE79',
#       'relation': 'isCitedBy',
#       'scheme': 'url'},
#      {'identifier': '10.11646/zootaxa.4276.4.3',
#       'relation': 'isPartOf',
#       'scheme': 'doi'},
#      {'identifier': 'urn:lsid:plazi.org:pub:BA3FD713CE4E5C486C3DFFCFFF89FFA9',
#       'relation': 'isPartOf',
#       'scheme': 'lsid'},
#      {'identifier': 'https://zenodo.org/record/807901',
#       'relation': 'isPartOf',
#       'scheme': 'url'},
#      {'identifier': '10.5281/zenodo.807904',
#       'relation': 'isPartOf',
#       'scheme': 'doi'}],
#     'relations': {'version': [{'count': 1,
#        'index': 0,
#        'is_last': True,
#        'last_child': {'pid_type': 'recid', 'pid_value': '807905'},
#        'parent': {'pid_type': 'recid', 'pid_value': '807904'}}]},
#     'resource_type': {'subtype': 'figure', 'title': 'Figure', 'type': 'image'},
#     'title': 'FIGURE 2 in A comprehensive and integrative re-description of Synchaeta tremula (Müller, 1786) and the newly rediscovered Synchaeta tremuloida Pourriot, 1965 (Rotifera: Synchaetidae)'},
#    'owners': [1161],
#    'revision': 1,
#    'updated': '2017-06-14T07:41:32.208116+00:00'},
#   {'conceptdoi': '10.5281/zenodo.807944',
#    'conceptrecid': '807944',
#    'created': '2017-06-14T07:50:23.419438+00:00',
#    'doi': '10.5281/zenodo.807945',
#    'id': 807945,
#    'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807945.svg',
#     'bucket': 'https://zenodo.org/api/files/0a4a6406-5031-4b5e-bd6c-5142ec9fc715',
#     'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807944.svg',
#     'conceptdoi': 'https://doi.org/10.5281/zenodo.807944',
#     'doi': 'https://doi.org/10.5281/zenodo.807945',
#     'html': 'https://zenodo.org/record/807945',
#     'latest': 'https://zenodo.org/api/records/807945',
#     'latest_html': 'https://zenodo.org/record/807945',
#     'self': 'https://zenodo.org/api/records/807945'},
#    'metadata': {'access_right': 'open',
#     'access_right_category': 'success',
#     'communities': [{'id': 'biosyslit'}],
#     'creators': [{'name': 'Marusik'}, {'name': 'Omelko'}, {'name': 'Koponen'}],
#     'description': 'Figs 4 ‒ 9. Male of Gongylidioides ussuricus. 4 ‒ habitus, lateral; 5 – the same, dorsal; 6 – palp, retrolateral; 7 – palp, ventral; 8 – palp, prolateral; 9 – palp, dorsal. Scale = 0.2 mm if not otherwise indicated.',
#     'doi': '10.5281/zenodo.807945',
#     'keywords': ['Biodiversity',
#      'Taxonomy',
#      'Animalia',
#      'Arthropoda',
#      'Arachnida',
#      'Araneae',
#      'Linyphiidae',
#      'Gongylidioides'],
#     'license': {'id': 'notspecified'},
#     'publication_date': '2016-12-31',
#     'related_identifiers': [{'identifier': 'http://treatment.plazi.org/id/420AC67D7600DB17FFAF0326C9C1C368',
#       'relation': 'isCitedBy',
#       'scheme': 'url'},
#      {'identifier': '10.5281/zenodo.807941',
#       'relation': 'isPartOf',
#       'scheme': 'doi'},
#      {'identifier': 'urn:lsid:plazi.org:pub:BE33BE057603DB13FFDE024BCB37C220',
#       'relation': 'isPartOf',
#       'scheme': 'lsid'},
#      {'identifier': 'https://zenodo.org/record/807941',
#       'relation': 'isPartOf',
#       'scheme': 'url'},
#      {'identifier': '10.5281/zenodo.807944',
#       'relation': 'isPartOf',
#       'scheme': 'doi'}],
#     'relations': {'version': [{'count': 1,
#        'index': 0,
#        'is_last': True,
#        'last_child': {'pid_type': 'recid', 'pid_value': '807945'},
#        'parent': {'pid_type': 'recid', 'pid_value': '807944'}}]},
#     'resource_type': {'subtype': 'figure', 'title': 'Figure', 'type': 'image'},
#     'title': 'Figs 4 ‒ 9 in Rare And New For The Fauna Of The Russian Far East Spiders (Aranei)'},
#    'owners': [1161],
#    'revision': 1,
#    'updated': '2017-06-14T07:50:23.618449+00:00'},
#   {'conceptdoi': '10.5281/zenodo.807946',
#    'conceptrecid': '807946',
#    'created': '2017-06-14T07:50:26.261471+00:00',
#    'doi': '10.5281/zenodo.807947',
#    'id': 807947,
#    'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807947.svg',
#     'bucket': 'https://zenodo.org/api/files/b0ffc8e8-5620-42e0-96ee-e67b8d5cffad',
#     'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807946.svg',
#     'conceptdoi': 'https://doi.org/10.5281/zenodo.807946',
#     'doi': 'https://doi.org/10.5281/zenodo.807947',
#     'html': 'https://zenodo.org/record/807947',
#     'latest': 'https://zenodo.org/api/records/807947',
#     'latest_html': 'https://zenodo.org/record/807947',
#     'self': 'https://zenodo.org/api/records/807947'},
#    'metadata': {'access_right': 'open',
#     'access_right_category': 'success',
#     'communities': [{'id': 'biosyslit'}],
#     'creators': [{'name': 'Marusik'}, {'name': 'Omelko'}, {'name': 'Koponen'}],
#     'description': 'Figs 10 ‒ 14. Male and female of " Oreonetides " longembolus. 10 – male habitus, dorsal; 11 – female habitus, dorsal; 12 – epigyne, ventral; 13, 14 – male palp, pro- and retrolateral. Scale = 0.2 mm if not otherwise indicated.',
#     'doi': '10.5281/zenodo.807947',
#     'keywords': ['Biodiversity',
#      'Taxonomy',
#      'Animalia',
#      'Arthropoda',
#      'Arachnida',
#      'Araneae',
#      'Linyphiidae',
#      'Oreonetides'],
#     'license': {'id': 'notspecified'},
#     'publication_date': '2016-12-31',
#     'related_identifiers': [{'identifier': 'http://treatment.plazi.org/id/420AC67D7607DB15FFAF0326CA39C098',
#       'relation': 'isCitedBy',
#       'scheme': 'url'},
#      {'identifier': '10.5281/zenodo.807941',
#       'relation': 'isPartOf',
#       'scheme': 'doi'},
#      {'identifier': 'urn:lsid:plazi.org:pub:BE33BE057603DB13FFDE024BCB37C220',
#       'relation': 'isPartOf',
#       'scheme': 'lsid'},
#      {'identifier': 'https://zenodo.org/record/807941',
#       'relation': 'isPartOf',
#       'scheme': 'url'},
#      {'identifier': '10.5281/zenodo.807946',
#       'relation': 'isPartOf',
#       'scheme': 'doi'}],
#     'relations': {'version': [{'count': 1,
#        'index': 0,
#        'is_last': True,
#        'last_child': {'pid_type': 'recid', 'pid_value': '807947'},
#        'parent': {'pid_type': 'recid', 'pid_value': '807946'}}]},
#     'resource_type': {'subtype': 'figure', 'title': 'Figure', 'type': 'image'},
#     'title': 'Figs 10 ‒ 14 in Rare And New For The Fauna Of The Russian Far East Spiders (Aranei)'},
#    'owners': [1161],
#    'revision': 1,
#    'updated': '2017-06-14T07:50:26.441983+00:00'},
#   {'conceptdoi': '10.5281/zenodo.807894',
#    'conceptrecid': '807894',
#    'created': '2017-06-14T07:39:16.859976+00:00',
#    'doi': '10.5281/zenodo.807895',
#    'id': 807895,
#    'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807895.svg',
#     'bucket': 'https://zenodo.org/api/files/24cdfb9c-c27d-4e48-8f19-d2e40b12a3dc',
#     'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807894.svg',
#     'conceptdoi': 'https://doi.org/10.5281/zenodo.807894',
#     'doi': 'https://doi.org/10.5281/zenodo.807895',
#     'html': 'https://zenodo.org/record/807895',
#     'latest': 'https://zenodo.org/api/records/807895',
#     'latest_html': 'https://zenodo.org/record/807895',
#     'self': 'https://zenodo.org/api/records/807895'},
#    'metadata': {'access_conditions': '<p>Visionierung auf Anfrage</p>',
#     'access_right': 'restricted',
#     'access_right_category': 'danger',
#     'communities': [{'id': 'buchjahr'}],
#     'creators': [{'name': 'Sidler, Maja'}],
#     'description': '<p>Filmische Buchbesprechung zum Werk</p>\n\n<p>Fricker, Ursula. (2016). <em>Lügen von gestern und heute : Roman</em> (Originalausgabe ed.). München: Dtv.</p>',
#     'doi': '10.5281/zenodo.807895',
#     'keywords': ['Schweizer Buchjahr',
#      'Buchjahr 2016',
#      'Buchbesprechung',
#      'Videorezension'],
#     'publication_date': '2016-09-30',
#     'related_identifiers': [{'identifier': '10.5281/zenodo.807894',
#       'relation': 'isPartOf',
#       'scheme': 'doi'}],
#     'relations': {'version': [{'count': 1,
#        'index': 0,
#        'is_last': True,
#        'last_child': {'pid_type': 'recid', 'pid_value': '807895'},
#        'parent': {'pid_type': 'recid', 'pid_value': '807894'}}]},
#     'resource_type': {'title': 'Video/Audio', 'type': 'video'},
#     'title': 'Lügen von gestern und heute / Ursula Fricker [Videorezension]'},
#    'owners': [24712],
#    'revision': 3,
#    'updated': '2017-06-14T07:48:12.392489+00:00'},
#   {'conceptdoi': '10.5281/zenodo.807920',
#    'conceptrecid': '807920',
#    'created': '2017-06-14T07:45:34.489774+00:00',
#    'doi': '10.5281/zenodo.807921',
#    'id': 807921,
#    'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807921.svg',
#     'bucket': 'https://zenodo.org/api/files/80e7410e-1073-4970-8e49-cd23bb3e35b4',
#     'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807920.svg',
#     'conceptdoi': 'https://doi.org/10.5281/zenodo.807920',
#     'doi': 'https://doi.org/10.5281/zenodo.807921',
#     'html': 'https://zenodo.org/record/807921',
#     'latest': 'https://zenodo.org/api/records/807921',
#     'latest_html': 'https://zenodo.org/record/807921',
#     'self': 'https://zenodo.org/api/records/807921'},
#    'metadata': {'access_conditions': '<p>Visionierung auf Anfrage</p>',
#     'access_right': 'restricted',
#     'access_right_category': 'danger',
#     'communities': [{'id': 'buchjahr'}],
#     'creators': [{'name': 'Hug, Halina'}],
#     'description': '<p>Filmische Buchbesprechung zum Werk</p>\n\n<p>Langenegger, Lorenz. (2016). <em>Dorffrieden : Roman</em>. Salzburg: Jung und Jung.</p>',
#     'doi': '10.5281/zenodo.807921',
#     'keywords': ['Schweizer Buchjahr',
#      'Buchjahr 2016',
#      'Buchbesprechung',
#      'Videorezension'],
#     'publication_date': '2016-09-30',
#     'related_identifiers': [{'identifier': '10.5281/zenodo.807920',
#       'relation': 'isPartOf',
#       'scheme': 'doi'}],
#     'relations': {'version': [{'count': 1,
#        'index': 0,
#        'is_last': True,
#        'last_child': {'pid_type': 'recid', 'pid_value': '807921'},
#        'parent': {'pid_type': 'recid', 'pid_value': '807920'}}]},
#     'resource_type': {'title': 'Video/Audio', 'type': 'video'},
#     'title': 'Dorffrieden / Lorenz Langenegger [Videorezension]'},
#    'owners': [24712],
#    'revision': 2,
#    'updated': '2017-06-14T07:48:57.864089+00:00'},
#   {'conceptdoi': '10.5281/zenodo.807940',
#    'conceptrecid': '807940',
#    'created': '2017-06-14T07:50:56.493766+00:00',
#    'doi': '10.5281/zenodo.807941',
#    'id': 807941,
#    'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807941.svg',
#     'bucket': 'https://zenodo.org/api/files/94100d8e-33ae-4fa9-ae24-a5d11fb8f298',
#     'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807940.svg',
#     'conceptdoi': 'https://doi.org/10.5281/zenodo.807940',
#     'doi': 'https://doi.org/10.5281/zenodo.807941',
#     'html': 'https://zenodo.org/record/807941',
#     'latest': 'https://zenodo.org/api/records/807941',
#     'latest_html': 'https://zenodo.org/record/807941',
#     'self': 'https://zenodo.org/api/records/807941'},
#    'metadata': {'access_right': 'closed',
#     'access_right_category': 'danger',
#     'communities': [{'id': 'biosyslit'}],
#     'creators': [{'name': 'Marusik'}, {'name': 'Omelko'}, {'name': 'Koponen'}],
#     'description': 'Marusik, Omelko, Koponen (2016): Rare And New For The Fauna Of The Russian Far East Spiders (Aranei). Far Eastern Entomologist 317: 1-15, DOI: 10.5281/zenodo.807941, URL: http/urn:lsid:zoobank.org:pub:3B5BDD6C-20E4-4792-B524-EF26D01F0865',
#     'doi': '10.5281/zenodo.807941',
#     'journal': {'pages': '1-15',
#      'title': 'Far Eastern Entomologist',
#      'volume': '317'},
#     'keywords': ['Biodiversity',
#      'Taxonomy',
#      'Animalia',
#      'Arthropoda',
#      'Arachnida',
#      'Araneae',
#      'Linyphiidae',
#      'Mimetidae',
#      'Tetragnathidae',
#      'Theridiidae'],
#     'publication_date': '2016-12-31',
#     'references': ['Eskov, K.Y. 1984. New and little known genera and species of spiders (Aranei, Linyphiidae) from the Far East. Zoologicheskii Zhurnal, 63(9): 1337-1344. [In Russian].',
#      'Eskov, K.Y. 1991. On the taxonomy and zoogeography of the spider genera Maro and Oreonetides (Aranei, Linyphiidae). Zoologicheskii Zhurnal, 70(4): 45-54. [In Russian].',
#      'Eskov, K.Y. 1992. A restudy of the generic composition of the linyphiid spider fauna of the Far East (Araneida: Linyphiidae). Entomologica Scandinavica, 23: 153-168.',
#      'Eskov, K.Y. 1994. Catalogue of the linyphiid spiders of northern Asia (Arachnida, Araneae, Linyphiidae). Pensoft Publishers, Sofia. 144 pp.',
#      'Hayashi, T. 1986. A new Japanese spider of the genus Agroeca (Araneae: Clubionidae). Proceedings of the Japanese Society of Systematic Zoology, 33: 23-28.',
#      'Kamura, T. & Hayashi, T. 2009. Liocranidae. P. 549-550. In: Ono, H. (ed.). The Spiders of Japan with keys to the families and genera and illustrations of the species. Tokai University Press, Kanagawa.',
#      'Kim, J. P., Kim, S. D. & Lee, Y. B. 1999. A revisional study of the Korean spiders, family Tetragnathidae Menge, 186 6 (Arachnida: Araneae). Korean Arachnology, 15(2): 41-100.',
#      'Knoflach, B. 1999. The comb-footed spider genera Neottiura and Coleosoma in Europe (Araneae, Theridiidae). Mitteilungen der Schweizerischen Entomologischen Gesellschaft, 72: 341-371.',
#      'Kronestedt, T., Marusik, Y.M. & Omelko, M.M. 2014. Studies on species of Holarctic Pardosa groups (Araneae, Lycosidae). VIII. The Palearctic species of the Pardosa nigra group. Zootaxa, 3894(1): 33-60. DOI: http//doi.org/10.11646/zootaxa.3894.1.5',
#      'Marusik, Y.M. 1989. New data on the fauna and synonymy of the USSR spiders (Arachnida, Aranei). P. 39-52. In: Lange, A.B. (ed.) Fauna i Ekologiy Paukov i Skorpionov: Arakhnologicheskii Sbornik. Akademia Nauk SSSR, Moscow. [In Russian].',
#      'Marusik, Y.M., Azarkina, G.N. & Koponen, S. 2004. A survey of east Palearctic Lycosidae (Aranei). II. Genus Acantholycosa F. Dahl, 1908 and related new genera. Arthropoda Selecta, 12(2): 101-148.',
#      'Marusik, Y.M. & Koponen, S. 2000. New data on spiders (Aranei) from the Maritime Province, Russian Far East. Arthropoda Selecta, 9(1): 55-68.',
#      'Marusik, Y.M. & Koponen, S. 2008. Obituary. Michael Ilmari Saaristo (1938-2008). Arthropoda Selecta, 17(1): 4-16.',
#      'Marusik Yu.M., Mikhailov K.G. & Omelko M.M. 2015a. Taxonomic notes on spiders (Arachnida: Aranei) from the Russian Far East. Arthropoda Selecta, 24(1): 117-124.',
#      'Marusik Y.M., Omelko M.M., Simonov P.S. & Koponen S. 2015b. New data about orbweaving spiders (Aranei: Araneidae and Tetragnathidae) from the Russian Far East. Arthropoda Selecta, 24(2): 207-214.',
#      'Mikhailov, K.G. 2013. The spiders (Arachnida: Aranei) of Russia and adjacent countries: a non-annotated checklist. Arthropoda Selecta, Supplement, 3: 1-262.',
#      'Mikhailov, K.G. & Temereva, E.N. 2015. Spiders (Aranei) of Vostok Biological Station, Maritime Province, Russia. Arthropoda Selecta, 24(4): 473-475.',
#      'Saaristo, M.I. 1971. Revision of the genus Maro O.P.-Cambridge (Araneae, Linyphiidae). Annales Zoologici Fennici, 8: 463-482.',
#      'Song, D.X., Zhu, M.S. & Chen, J. 1999. The Spiders of China. Hebei University of Science and Techology Publishing House, Shijiazhuang. 640 pp.',
#      'Tanasevitch, A.V. 2006. New or little-known Maro O.P.-Cambridge from Siberia and the Russian Far East (Aranei: Linyphiidae: Micronetinae). Arthropoda Selecta, 14(3): 259- 268.',
#      'Tanikawa, A. 2007. An identification guide to the Japanese spiders of the families Araneidae, Nephilidae and Tetragnathidae. Arachnological Society of Japan. 121 pp.',
#      'Tanikawa, A. 2009. Hersiliidae. Nephilidae, Tetragnathidae, Araneidae. P. 149, 403-463. In: Ono, H. (ed.). The Spiders of Japan with keys to the families and genera and illustrations of the species. Tokai University Press, Kanagawa.',
#      'World Spider Catalog. 2016. World Spider Catalog, version 16.5. Natural History Museum Bern. Available from: http://wsc.nmbe.ch (Accessed 30 January 2 015).',
#      'Wunderlich, J. & Li, S.Q. 1995. Three new spider species and one new genus (family Linyphiidae) from China (Arachnida: Araneae). Beitrage zur Araneologie, 4: 335-342.',
#      'Yoshida, H. & Tanikawa, A. 2009. Mimetidae. P. 251-252. In: Ono, H. (ed.). The Spiders of Japan with keys to the families and genera and illustrations of the species. Tokai University Press, Kanagawa.',
#      'Yoshida, H. 2009a. Theridiidae. P. 356-393. In: Ono, H. (Ed.). The Spiders of Japan with keys to the families and genera and illustrations of the species. Tokai University Press, Kanagawa.',
#      'Yoshida, H. 2009b. The spider genus Leucauge (Araneae: Tetragnathidae) from Taiwan. Acta Arachnologica, Tokyo, 58(1): 11-18.',
#      'Zhu, M.S., Song, D.X. & Zhang, J.X. 2003. Fauna Sinica: Invertebrata Vol. 35: Arachnida: Araneae: Tetragnathidae. Science Press, Beijing. vii + 418 pp.'],
#     'related_identifiers': [{'identifier': 'http://treatment.plazi.org/id/420AC67D7601DB11FE1D0382C993C3C1',
#       'relation': 'hasPart',
#       'scheme': 'url'},
#      {'identifier': 'http://treatment.plazi.org/id/420AC67D7601DB10FFAC004DCAF7C367',
#       'relation': 'hasPart',
#       'scheme': 'url'},
#      {'identifier': 'http://treatment.plazi.org/id/420AC67D7600DB17FFAF0326C9C1C368',
#       'relation': 'hasPart',
#       'scheme': 'url'},
#      {'identifier': 'http://treatment.plazi.org/id/420AC67D7607DB15FFAF0326CA39C098',
#       'relation': 'hasPart',
#       'scheme': 'url'},
#      {'identifier': 'http://treatment.plazi.org/id/420AC67D7605DB15FFAF014CCBAEC694',
#       'relation': 'hasPart',
#       'scheme': 'url'},
#      {'identifier': 'http://treatment.plazi.org/id/420AC67D7605DB14FFAF0749C901C3A0',
#       'relation': 'hasPart',
#       'scheme': 'url'},
#      {'identifier': 'http://treatment.plazi.org/id/420AC67D7604DB1BFFAF0746CA3FC3E2',
#       'relation': 'hasPart',
#       'scheme': 'url'},
#      {'identifier': 'http://treatment.plazi.org/id/420AC67D760BDB1AFFAF0776CA4FC7F6',
#       'relation': 'hasPart',
#       'scheme': 'url'},
#      {'identifier': 'http://treatment.plazi.org/id/420AC67D7609DB19FFAF067FC902C7C2',
#       'relation': 'hasPart',
#       'scheme': 'url'},
#      {'identifier': 'http://treatment.plazi.org/id/420AC67D7608DB18FEE4028ECB83C348',
#       'relation': 'hasPart',
#       'scheme': 'url'},
#      {'identifier': 'http://treatment.plazi.org/id/420AC67D760FDB1FFFAF02DCC8FBC063',
#       'relation': 'hasPart',
#       'scheme': 'url'},
#      {'identifier': 'http://treatment.plazi.org/id/420AC67D760FDB1EFFAF0761CB83C3E2',
#       'relation': 'hasPart',
#       'scheme': 'url'},
#      {'identifier': 'Kronestedt,T.,Marusik,Y.M.&Omelko,M.M.2014.StudiesonspeciesofHolarcticPardosagroups(Araneae,Lycosidae).VIII.ThePalearcticspeciesofthePardosanigragroup.Zootaxa,3894(1):33-60.DOI:http//doi.org/10.11646/zootaxa.3894.1.5',
#       'relation': 'cites',
#       'scheme': 'handle'},
#      {'identifier': '10.5281/zenodo.807943',
#       'relation': 'hasPart',
#       'scheme': 'doi'},
#      {'identifier': 'urn:lsid:plazi.org:fig:2-130-989-779-1385',
#       'relation': 'hasPart',
#       'scheme': 'lsid'},
#      {'identifier': 'http://zenodo.org/record/807943',
#       'relation': 'hasPart',
#       'scheme': 'url'},
#      {'identifier': '10.5281/zenodo.807945',
#       'relation': 'hasPart',
#       'scheme': 'doi'},
#      {'identifier': 'urn:lsid:plazi.org:fig:3-134-995-578-1422',
#       'relation': 'hasPart',
#       'scheme': 'lsid'},
#      {'identifier': 'http://zenodo.org/record/807945',
#       'relation': 'hasPart',
#       'scheme': 'url'},
#      {'identifier': '10.5281/zenodo.807947',
#       'relation': 'hasPart',
#       'scheme': 'doi'},
#      {'identifier': 'urn:lsid:plazi.org:fig:4-115-962-630-1407',
#       'relation': 'hasPart',
#       'scheme': 'lsid'},
#      {'identifier': 'http://zenodo.org/record/807947',
#       'relation': 'hasPart',
#       'scheme': 'url'},
#      {'identifier': '10.5281/zenodo.807949',
#       'relation': 'hasPart',
#       'scheme': 'doi'},
#      {'identifier': 'urn:lsid:plazi.org:fig:5-113-982-144-1187',
#       'relation': 'hasPart',
#       'scheme': 'lsid'},
#      {'identifier': 'http://zenodo.org/record/807949',
#       'relation': 'hasPart',
#       'scheme': 'url'},
#      {'identifier': '10.5281/zenodo.807951',
#       'relation': 'hasPart',
#       'scheme': 'doi'},
#      {'identifier': 'urn:lsid:plazi.org:fig:7-232-899-415-1138',
#       'relation': 'hasPart',
#       'scheme': 'lsid'},
#      {'identifier': 'http://zenodo.org/record/807951',
#       'relation': 'hasPart',
#       'scheme': 'url'},
#      {'identifier': '10.5281/zenodo.807953',
#       'relation': 'hasPart',
#       'scheme': 'doi'},
#      {'identifier': 'urn:lsid:plazi.org:fig:8-147-980-454-1182',
#       'relation': 'hasPart',
#       'scheme': 'lsid'},
#      {'identifier': 'http://zenodo.org/record/807953',
#       'relation': 'hasPart',
#       'scheme': 'url'},
#      {'identifier': '10.5281/zenodo.807955',
#       'relation': 'hasPart',
#       'scheme': 'doi'},
#      {'identifier': 'urn:lsid:plazi.org:fig:10-159-962-160-980',
#       'relation': 'hasPart',
#       'scheme': 'lsid'},
#      {'identifier': 'http://zenodo.org/record/807955',
#       'relation': 'hasPart',
#       'scheme': 'url'},
#      {'identifier': '10.5281/zenodo.807957',
#       'relation': 'hasPart',
#       'scheme': 'doi'},
#      {'identifier': 'urn:lsid:plazi.org:fig:11-147-978-375-1422',
#       'relation': 'hasPart',
#       'scheme': 'lsid'},
#      {'identifier': 'http://zenodo.org/record/807957',
#       'relation': 'hasPart',
#       'scheme': 'url'},
#      {'identifier': '10.5281/zenodo.807959',
#       'relation': 'hasPart',
#       'scheme': 'doi'},
#      {'identifier': 'urn:lsid:plazi.org:fig:12-150-971-596-1186',
#       'relation': 'hasPart',
#       'scheme': 'lsid'},
#      {'identifier': 'http://zenodo.org/record/807959',
#       'relation': 'hasPart',
#       'scheme': 'url'},
#      {'identifier': '10.5281/zenodo.807940',
#       'relation': 'isPartOf',
#       'scheme': 'doi'}],
#     'relations': {'version': [{'count': 1,
#        'index': 0,
#        'is_last': True,
#        'last_child': {'pid_type': 'recid', 'pid_value': '807941'},
#        'parent': {'pid_type': 'recid', 'pid_value': '807940'}}]},
#     'resource_type': {'subtype': 'article',
#      'title': 'Journal article',
#      'type': 'publication'},
#     'title': 'Rare And New For The Fauna Of The Russian Far East Spiders (Aranei)'},
#    'owners': [1161],
#    'revision': 1,
#    'updated': '2017-06-14T07:50:56.694540+00:00'},
#   {'conceptdoi': '10.5281/zenodo.807972',
#    'conceptrecid': '807972',
#    'created': '2017-06-14T07:53:13.747931+00:00',
#    'doi': '10.5281/zenodo.807973',
#    'id': 807973,
#    'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807973.svg',
#     'bucket': 'https://zenodo.org/api/files/d3e8f561-62c8-445b-9321-7e380e49687d',
#     'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807972.svg',
#     'conceptdoi': 'https://doi.org/10.5281/zenodo.807972',
#     'doi': 'https://doi.org/10.5281/zenodo.807973',
#     'html': 'https://zenodo.org/record/807973',
#     'latest': 'https://zenodo.org/api/records/807973',
#     'latest_html': 'https://zenodo.org/record/807973',
#     'self': 'https://zenodo.org/api/records/807973'},
#    'metadata': {'access_right': 'open',
#     'access_right_category': 'success',
#     'communities': [{'id': 'biosyslit'}],
#     'creators': [{'name': 'Monniot, Françoise'},
#      {'name': 'López-Legentil, Susanna'}],
#     'description': 'FIGURE 1. Fimbrora calsubia. A and B, ventral and dorsal sides of a specimen. C, neural area. D, detail of the ramified tissues of the posterior part of the abdomen stained with hemalum.',
#     'doi': '10.5281/zenodo.807973',
#     'keywords': ['Biodiversity',
#      'Taxonomy',
#      'Animalia',
#      'Chordata',
#      'Ascidiacea',
#      'Enterogona',
#      'Ascidiidae',
#      'Fimbrora'],
#     'license': {'id': 'notspecified'},
#     'publication_date': '2017-12-31',
#     'related_identifiers': [{'identifier': 'http://treatment.plazi.org/id/D02201375E04D10F35AD84FA802C39A2',
#       'relation': 'isCitedBy',
#       'scheme': 'url'},
#      {'identifier': '10.11646/zootaxa.4276.4.5',
#       'relation': 'isPartOf',
#       'scheme': 'doi'},
#      {'identifier': 'urn:lsid:plazi.org:pub:2C1B794F5E06D10B353A8426813C3A4F',
#       'relation': 'isPartOf',
#       'scheme': 'lsid'},
#      {'identifier': 'https://zenodo.org/record/807971',
#       'relation': 'isPartOf',
#       'scheme': 'url'},
#      {'identifier': '10.5281/zenodo.807972',
#       'relation': 'isPartOf',
#       'scheme': 'doi'}],
#     'relations': {'version': [{'count': 1,
#        'index': 0,
#        'is_last': True,
#        'last_child': {'pid_type': 'recid', 'pid_value': '807973'},
#        'parent': {'pid_type': 'recid', 'pid_value': '807972'}}]},
#     'resource_type': {'subtype': 'figure', 'title': 'Figure', 'type': 'image'},
#     'title': 'FIGURE 1. Fimbrora calsubia. A and B in Deep-sea ascidians from Papua New Guinea'},
#    'owners': [1161],
#    'revision': 1,
#    'updated': '2017-06-14T07:53:13.968550+00:00'},
#   {'conceptdoi': '10.5281/zenodo.807952',
#    'conceptrecid': '807952',
#    'created': '2017-06-14T07:50:38.406749+00:00',
#    'doi': '10.5281/zenodo.807953',
#    'id': 807953,
#    'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807953.svg',
#     'bucket': 'https://zenodo.org/api/files/5e0257b5-d795-4da7-b90c-cfc3defbac85',
#     'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807952.svg',
#     'conceptdoi': 'https://doi.org/10.5281/zenodo.807952',
#     'doi': 'https://doi.org/10.5281/zenodo.807953',
#     'html': 'https://zenodo.org/record/807953',
#     'latest': 'https://zenodo.org/api/records/807953',
#     'latest_html': 'https://zenodo.org/record/807953',
#     'self': 'https://zenodo.org/api/records/807953'},
#    'metadata': {'access_right': 'open',
#     'access_right_category': 'success',
#     'communities': [{'id': 'biosyslit'}],
#     'creators': [{'name': 'Marusik'}, {'name': 'Omelko'}, {'name': 'Koponen'}],
#     'description': 'Figs 28 - 31. Female of Mimetus testaceus. 28, 29 – habitus, dorsal and lateral; 30, 31 – epigyne, caudal and ventral. Scale = 0.2 mm if not otherwise indicated.',
#     'doi': '10.5281/zenodo.807953',
#     'keywords': ['Biodiversity',
#      'Taxonomy',
#      'Animalia',
#      'Arthropoda',
#      'Arachnida',
#      'Araneae',
#      'Mimetidae',
#      'Mimetus'],
#     'license': {'id': 'notspecified'},
#     'publication_date': '2016-12-31',
#     'related_identifiers': [{'identifier': 'http://treatment.plazi.org/id/420AC67D7604DB1BFFAF0746CA3FC3E2',
#       'relation': 'isCitedBy',
#       'scheme': 'url'},
#      {'identifier': '10.5281/zenodo.807941',
#       'relation': 'isPartOf',
#       'scheme': 'doi'},
#      {'identifier': 'urn:lsid:plazi.org:pub:BE33BE057603DB13FFDE024BCB37C220',
#       'relation': 'isPartOf',
#       'scheme': 'lsid'},
#      {'identifier': 'https://zenodo.org/record/807941',
#       'relation': 'isPartOf',
#       'scheme': 'url'},
#      {'identifier': '10.5281/zenodo.807952',
#       'relation': 'isPartOf',
#       'scheme': 'doi'}],
#     'relations': {'version': [{'count': 1,
#        'index': 0,
#        'is_last': True,
#        'last_child': {'pid_type': 'recid', 'pid_value': '807953'},
#        'parent': {'pid_type': 'recid', 'pid_value': '807952'}}]},
#     'resource_type': {'subtype': 'figure', 'title': 'Figure', 'type': 'image'},
#     'title': 'Figs 28 - 31 in Rare And New For The Fauna Of The Russian Far East Spiders (Aranei)'},
#    'owners': [1161],
#    'revision': 1,
#    'updated': '2017-06-14T07:50:38.617126+00:00'},
#   {'conceptrecid': '807960',
#    'created': '2017-06-14T07:52:08.229754+00:00',
#    'doi': '10.1080/09397140.2015.1095525',
#    'id': 807961,
#    'links': {'badge': 'https://zenodo.org/badge/doi/10.1080/09397140.2015.1095525.svg',
#     'bucket': 'https://zenodo.org/api/files/7ae2adcb-df5a-4c04-8c7c-f5486d9738cb',
#     'doi': 'https://doi.org/10.1080/09397140.2015.1095525',
#     'html': 'https://zenodo.org/record/807961',
#     'latest': 'https://zenodo.org/api/records/807961',
#     'latest_html': 'https://zenodo.org/record/807961',
#     'self': 'https://zenodo.org/api/records/807961'},
#    'metadata': {'access_right': 'closed',
#     'access_right_category': 'danger',
#     'communities': [{'id': 'biosyslit'}],
#     'creators': [{'name': 'Zonstein, Sergei'},
#      {'name': 'Marusik, Yuri'},
#      {'name': 'Omelko, Mikhail'}],
#     'description': 'Zonstein, Sergei, Marusik, Yuri, Omelko, Mikhail (2015): A survey of spider taxa new to Israel (Arachnida: Araneae). Zoology in the Middle East 61 (4): 372-385, DOI: 10.1080/09397140.2015.1095525',
#     'doi': '10.1080/09397140.2015.1095525',
#     'journal': {'issue': '4',
#      'pages': '372-385',
#      'title': 'Zoology in the Middle East',
#      'volume': '61'},
#     'keywords': ['Biodiversity',
#      'Taxonomy',
#      'Animalia',
#      'Arthropoda',
#      'Arachnida',
#      'Araneae',
#      'Dictynidae',
#      'Hahniidae',
#      'Linyphiidae',
#      'Liocranidae',
#      'Lycosidae',
#      'Mimetidae',
#      'Mysmenidae',
#      'Pholcidae',
#      'Phyxelididae',
#      'Prodidomidae',
#      'Salticidae',
#      'Theridiidae',
#      'Corinnidae',
#      'Uloboridae'],
#     'publication_date': '2015-12-31',
#     'references': ['Bayram, A., Kunt, K. B., & Danisman, T. (2014): The checklist of the spiders of Turkey. Version 2014. www.kazimcapaci.com/spidersofturkey.htm [accessed 11 January 2015].',
#      'Bosmans, R., Baert, L., Bosselaers, J., De Koninck, H, Maelfait, J.-P. & Van Keer, J. (2009): Spiders of Lesbos (Greece). Nieuwsbrief van de Belgische Arachnologische Vereniging, 24 (suppl.), 1-70.',
#      'Bosmans, R. (2011): On some new or rare spider species from Lesbos, Greece (Araneae: Agelenidae, Amaurobiidae, Corinnidae, Gnaphosidae, Liocranidae). Arachnologische Mitteilungen, 40, 15-22.',
#      'Cambridge, O. P. (1876): Catalogue of a collection of spiders made in Egypt, with descriptions of new species and characters of a new genus. Proceedings of the Zoological Society of London, 1876, 541-630.',
#      "Denis, J. (1947): Spiders. In: Results of the Armstrong College expedition to Siwa Oasis (Libyan desert), 1935. Bulletin de la Societe Fouad Ier d'Entomologie, 31, 17-103.",
#      'Dunin, P. M., Buchar, J., & Absolon, K. (1986): Die dritte Palaarktische Aulonia -Art: Aulonia kratochvili sp. n. (Araneida, Lycosidae). Vestnik Ceskoslovenske Zoologicke Spolecnosti v Praze, 50, 28-32.',
#      'Griswold, C. E. (1990): A revision and phylogenetic analysis of the spider subfamily Phyxelidinae (Araneae, Amaurobiidae). Bulletin of the American Museum of Natural History, 196, 1- 206.',
#      'Helsdingen, P.J. van (2014): Araneae.In: Fauna Europaea. Database European spiders and their distribution. Taxonomy. Version 2013.1. www.faunaeur.org [accessed on 11 January 2015]',
#      'Huber, B. A. (2002): Functional morphology of the genitalia in the spider Spermophora senoculata (Pholcidae, Araneae). Zoologischer Anzeiger, 241, 105-116.',
#      'Kovblyuk, M. M., Marusik, Y. M., Ponomarev, A. V., Gnelitsa, V. A., & Nadolny, A. A. (2011): Spiders (Arachnida: Aranei) of Abkhazia. Arthropoda Selecta, 20, 21-56.',
#      'Kovblyuk, M. M., & Nadolny, A. A. (2009): The spider genus Trachelas L. Koch, 1872 in Crimea and Caucasus with the description of Paratrachelas gen. n. (Aranei: Corinnidae). Arthropoda Selecta, 18, 35-46.',
#      'Kraus, O. (1967): Zur Spinnenfauna Deutschlands, II. Mysmena jobi n. sp., eine Symphytognathide in Mitteleuropa (Arachnida: Araneae: Symphytognathidae). Senckenbergiana biologica, 48, 387-399.',
#      'Kronestedt, T. (1997): First record of Aulonia kratochvili (Araneae, Lycosidae) from Europe. Arachnologische Mitteilungen, 14, 77-80.',
#      'Levy, G. (2007): Calommata (Atypidae) and new spider species (Araneae) from Israel. Zootaxa, 1551, 1-30.',
#      'Logunov, D. V., & Kronestedt, T. (2003): A review of the genus Talavera Peckham and Peckham, 1909 (Araneae, Salticidae). Journal of Natural History, 37, 1091-1154.',
#      'Logunov, D. V., & Marusik, Y. M. (2000): Miscellaneous notes on Palaearctic Salticidae (Arachnida: Aranei). Arthropoda Selecta, 8, 263-292.',
#      'Marusik, Y. M., Kunt, K. B., & Danisman, T. (2009): Spiders (Aranei) new to the fauna of Turkey. 2. New species records of Theridiidae. Arthropoda Selecta, 18: 69-75.',
#      'Marusik, Y. M., Ozkutuk, R. S., Kunt, K. B., & Kaya, R. S. (2011): Spiders (Araneae) new to the fauna of Turkey. 8. New records of Hahniidae and Dictynidae. Anadolu University Journal of Science and Technology -C, 1, 161-170.',
#      'Metzner, H. (1999): Die Springspinnen (Araneae, Salticidae) Griechenlands. Andrias, 14, 1-279.',
#      'Mikhailov, K. G. (2013): The spiders (Arachnida: Aranei) of Russia and adjacent countries: a non-annotated checklist. Arthropoda Selecta. Supplement, 3.',
#      'Otto, S. (2014): Caucasian Spiders. A faunistic database on the spiders of the Caucasus. Version 1.4. Internet: http://caucasus-spiders.info [accessed 11 January 2015].',
#      'Ozkutuk, R. S., Marusik, Y. M., Kunt, K. B., & Danisman, T. (2011): New records for spider (Araneae) fauna of Turkey: Paratrachelas maculatus (Thorell, 1875) [Corinnidae], Sintula retroversus (O. P.-Cambridge, 1875) [Linyphiidae] and Agroeca proxima (O. P.-Cambridge, 1871) [Liocranidae]. Biological Diversity Conservation, 4, 224-232.',
#      "Perez, P. J. A., & Blasco, F. A. (1986): Nota sobre los Prodidominae (Araneae: Gnaphosidae) de la Peninsula Iberica. Memoires de la Societe Royal Belge d'Entomologie, 33, 155-164.",
#      'Platnick, N. I., & Baehr, B. (2006): A revision of the Australasian ground spiders of the family Prodidomidae (Araneae, Gnaphosoidea). Bulletin of the American Museum of Natural History, 298, 1-287.',
#      'Platnick, N. (2014): The World Spider Catalog, Version 15. http://research.amnh.org/iz/spiders/catalog/INTRO1.html [accessed on 11 January 2015].',
#      'Proszynski, J. (1998): Description of new species of Phlegra (Araneae: Salticidae) from Israel. Israel Journal of Zoology, 44, 159-185.',
#      'Proszyski, J. (2000): On mostly new species of Salticidae (Aranei) from Levant. Arthropoda Selecta, 8, 231-262.',
#      'Proszyski, J. (2003): Salticidae (Araneae) of the Levant. Annales Zoologici (Warsaw), 53, 1-180.',
#      'Roberts, M. J. (1998): Spinnengids. Tirion, Baarn (the Netherlands).',
#      'Roewer, C. F. (1955): Katalog der Araneae von 1758 bis 1940, bzw. 1954. Bruxelles, 2, 1-1751.',
# ...
#       'relation': 'hasPart',
#       'scheme': 'lsid'},
#      {'identifier': 'http://zenodo.org/record/807969',
#       'relation': 'hasPart',
#       'scheme': 'url'}],
#     'relations': {'version': [{'count': 1,
#        'index': 0,
#        'is_last': True,
#        'last_child': {'pid_type': 'recid', 'pid_value': '807961'},
#        'parent': {'pid_type': 'recid', 'pid_value': '807960'}}]},
#     'resource_type': {'subtype': 'article',
#      'title': 'Journal article',
#      'type': 'publication'},
#     'title': 'A survey of spider taxa new to Israel (Arachnida: Araneae)'},
#    'owners': [1161],
#    'revision': 2,
#    'updated': '2017-06-14T08:06:08.354557+00:00'},
#   {'conceptdoi': '10.5281/zenodo.808025',
#    'conceptrecid': '808025',
#    'created': '2017-06-14T08:14:45.125488+00:00',
#    'doi': '10.5281/zenodo.808026',
#    'id': 808026,
#    'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.808026.svg',
#     'bucket': 'https://zenodo.org/api/files/f37070d7-1aa4-44f8-ac08-79756a10b2ce',
#     'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.808025.svg',
#     'conceptdoi': 'https://doi.org/10.5281/zenodo.808025',
#     'doi': 'https://doi.org/10.5281/zenodo.808026',
#     'html': 'https://zenodo.org/record/808026',
#     'latest': 'https://zenodo.org/api/records/808026',
#     'latest_html': 'https://zenodo.org/record/808026',
#     'self': 'https://zenodo.org/api/records/808026'},
#    'metadata': {'access_right': 'open',
#     'access_right_category': 'success',
#     'communities': [{'id': 'biosyslit'}],
#     'creators': [{'name': 'Reding, Jean-Paul G.'},
#      {'name': 'Bolard, Audrey'},
#      {'name': 'Vinçon, Gilles'}],
#     'description': 'FIGURE 1. Protonemura jurassica sp. n., male terminalia, lateral view. FIGURE 2. Protonemura jurassica sp. n., male terminalia, lateral view. FIGURE 3. Protonemura jurassica sp. n., male terminalia, dorsal view. FIGURE 4. Protonemura jurassica sp. n., male epiproct, lateral view.',
#     'doi': '10.5281/zenodo.808026',
#     'keywords': ['Biodiversity',
#      'Taxonomy',
#      'Animalia',
#      'Arthropoda',
#      'Insecta',
#      'Plecoptera',
#      'Nemouridae',
#      'Protonemura'],
#     'license': {'id': 'notspecified'},
#     'publication_date': '2017-12-31',
#     'related_identifiers': [{'identifier': 'http://treatment.plazi.org/id/03AD87AAFFB0DD2B30EC90DCFD91FE52',
#       'relation': 'isCitedBy',
#       'scheme': 'url'},
#      {'identifier': '10.11646/zootaxa.4276.4.7',
#       'relation': 'isPartOf',
#       'scheme': 'doi'},
#      {'identifier': 'urn:lsid:plazi.org:pub:FF94FFD2FFB1DD26307B9106FFEBFFA7',
#       'relation': 'isPartOf',
#       'scheme': 'lsid'},
#      {'identifier': 'https://zenodo.org/record/808024',
#       'relation': 'isPartOf',
#       'scheme': 'url'},
#      {'identifier': '10.5281/zenodo.808025',
#       'relation': 'isPartOf',
#       'scheme': 'doi'}],
#     'relations': {'version': [{'count': 1,
#        'index': 0,
#        'is_last': True,
#        'last_child': {'pid_type': 'recid', 'pid_value': '808026'},
#        'parent': {'pid_type': 'recid', 'pid_value': '808025'}}]},
#     'resource_type': {'subtype': 'figure', 'title': 'Figure', 'type': 'image'},
#     'title': 'FIGURE 1 in A new species of Protonemura Kempny, 1898 (Plecoptera: Nemouridae) from the French and Swiss Jura Mountains'},
#    'owners': [1161],
#    'revision': 1,
#    'updated': '2017-06-14T08:14:45.324237+00:00'},
#   {'conceptdoi': '10.5281/zenodo.807966',
#    'conceptrecid': '807966',
#    'created': '2017-06-14T07:51:57.859766+00:00',
#    'doi': '10.5281/zenodo.807967',
#    'id': 807967,
#    'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807967.svg',
#     'bucket': 'https://zenodo.org/api/files/aaf17651-e527-4096-9332-03349fc56291',
#     'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.807966.svg',
#     'conceptdoi': 'https://doi.org/10.5281/zenodo.807966',
#     'doi': 'https://doi.org/10.5281/zenodo.807967',
#     'html': 'https://zenodo.org/record/807967',
#     'latest': 'https://zenodo.org/api/records/807967',
#     'latest_html': 'https://zenodo.org/record/807967',
#     'self': 'https://zenodo.org/api/records/807967'},
#    'metadata': {'access_right': 'open',
#     'access_right_category': 'success',
#     'communities': [{'id': 'biosyslit'}],
#     'creators': [{'name': 'Zonstein, Sergei'},
#      {'name': 'Marusik, Yuri'},
#      {'name': 'Omelko, Mikhail'}],
#     'description': 'Figure 4. Female of Phyxelida anatolica. – a. habitus, lateral; b. abdomen, ventral. Scale = 0.2 mm if not otherwise indicated.',
#     'doi': '10.5281/zenodo.807967',
#     'keywords': ['Biodiversity',
#      'Taxonomy',
#      'Animalia',
#      'Arthropoda',
#      'Arachnida',
#      'Araneae',
#      'Phyxelididae',
#      'Phyxelida'],
#     'license': {'id': 'notspecified'},
#     'publication_date': '2015-12-31',
#     'related_identifiers': [{'identifier': 'http://treatment.plazi.org/id/039BF00B8C1EFFC9FF3FF9CC57BF1EA5',
#       'relation': 'isCitedBy',
#       'scheme': 'url'},
#      {'identifier': '10.1080/09397140.2015.1095525',
#       'relation': 'isPartOf',
#       'scheme': 'doi'},
#      {'identifier': 'urn:lsid:plazi.org:pub:FFA288738C19FFC1FFA7FFD054431A6B',
#       'relation': 'isPartOf',
#       'scheme': 'lsid'},
#      {'identifier': 'https://zenodo.org/record/807961',
#       'relation': 'isPartOf',
#       'scheme': 'url'},
#      {'identifier': 'https://zenodo.org/record/807961',
#       'relation': 'isPartOf',
#       'scheme': 'url'},
#      {'identifier': '10.5281/zenodo.807966',
#       'relation': 'isPartOf',
#       'scheme': 'doi'}],
#     'relations': {'version': [{'count': 1,
#        'index': 0,
#        'is_last': True,
#        'last_child': {'pid_type': 'recid', 'pid_value': '807967'},
#        'parent': {'pid_type': 'recid', 'pid_value': '807966'}}]},
#     'resource_type': {'subtype': 'figure', 'title': 'Figure', 'type': 'image'},
#     'title': 'Figure 4 in A survey of spider taxa new to Israel (Arachnida: Araneae)'},
#    'owners': [1161],
#    'revision': 2,
#    'updated': '2017-06-14T08:06:01.403743+00:00'},
#   {'conceptdoi': '10.5281/zenodo.808075',
#    'conceptrecid': '808075',
#    'created': '2017-06-14T08:23:59.320094+00:00',
#    'doi': '10.5281/zenodo.808076',
#    'id': 808076,
#    'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.808076.svg',
#     'bucket': 'https://zenodo.org/api/files/b23b1108-da31-4b8e-8455-b8f34ce40a29',
#     'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.808075.svg',
#     'conceptdoi': 'https://doi.org/10.5281/zenodo.808075',
#     'doi': 'https://doi.org/10.5281/zenodo.808076',
#     'html': 'https://zenodo.org/record/808076',
#     'latest': 'https://zenodo.org/api/records/808076',
#     'latest_html': 'https://zenodo.org/record/808076',
#     'self': 'https://zenodo.org/api/records/808076'},
#    'metadata': {'access_right': 'open',
#     'access_right_category': 'success',
#     'communities': [{'id': 'biosyslit'}],
#     'creators': [{'name': 'Vogel, Gernot'},
#      {'name': 'Lalremsanga, Hmar Tlawmte'}],
#     'description': 'FIGURE 4. Comparison of the heads of (A) the holotype of Blythia hmuifang sp. nov. (MZMU 714), (B) a paratype of Blythia hmuifang sp. nov. (MZMU 716) and (C) B. reticulata (MZU 802).',
#     'doi': '10.5281/zenodo.808076',
#     'keywords': ['Biodiversity',
#      'Taxonomy',
#      'Animalia',
#      'Chordata',
#      'Reptilia',
#      'Squamata',
#      'Colubridae',
#      'Blythia'],
#     'license': {'id': 'notspecified'},
#     'publication_date': '2017-12-31',
#     'related_identifiers': [{'identifier': 'http://treatment.plazi.org/id/83036772FFCB0A31FF4DFBA8002C86BD',
#       'relation': 'isCitedBy',
#       'scheme': 'url'},
#      {'identifier': '10.11646/zootaxa.4276.4.8',
#       'relation': 'isPartOf',
#       'scheme': 'doi'},
#      {'identifier': 'urn:lsid:plazi.org:pub:7F3A1F0AFFCA0A39FFDAFFB204348645',
#       'relation': 'isPartOf',
#       'scheme': 'lsid'},
#      {'identifier': 'https://zenodo.org/record/808066',
#       'relation': 'isPartOf',
#       'scheme': 'url'},
#      {'identifier': '10.5281/zenodo.808075',
#       'relation': 'isPartOf',
#       'scheme': 'doi'}],
#     'relations': {'version': [{'count': 1,
#        'index': 0,
#        'is_last': True,
#        'last_child': {'pid_type': 'recid', 'pid_value': '808076'},
#        'parent': {'pid_type': 'recid', 'pid_value': '808075'}}]},
#     'resource_type': {'subtype': 'figure', 'title': 'Figure', 'type': 'image'},
#     'title': 'FIGURE 4 in A second species of the genus Blythia Theobald, 1868 (Squamata: Colubridae) from Mizoram, India'},
#    'owners': [1161],
#    'revision': 1,
#    'updated': '2017-06-14T08:23:59.544770+00:00'},
#   {'conceptdoi': '10.5281/zenodo.808079',
#    'conceptrecid': '808079',
#    'created': '2017-06-14T08:24:05.924530+00:00',
#    'doi': '10.5281/zenodo.808080',
#    'id': 808080,
#    'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.808080.svg',
#     'bucket': 'https://zenodo.org/api/files/44e5cf06-82e1-414e-be43-00dd40911ed0',
#     'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.808079.svg',
#     'conceptdoi': 'https://doi.org/10.5281/zenodo.808079',
#     'doi': 'https://doi.org/10.5281/zenodo.808080',
#     'html': 'https://zenodo.org/record/808080',
#     'latest': 'https://zenodo.org/api/records/808080',
#     'latest_html': 'https://zenodo.org/record/808080',
#     'self': 'https://zenodo.org/api/records/808080'},
#    'metadata': {'access_right': 'open',
#     'access_right_category': 'success',
#     'communities': [{'id': 'biosyslit'}],
#     'creators': [{'name': 'Vogel, Gernot'},
#      {'name': 'Lalremsanga, Hmar Tlawmte'}],
#     'description': 'FIGURE 6. Comparison of the paratype of Blythia hmuifang sp. nov. left (MZMU 715, female) with a juvenile of Blythia reticulata (Blyth, 1854) right.',
#     'doi': '10.5281/zenodo.808080',
#     'keywords': ['Biodiversity',
#      'Taxonomy',
#      'Animalia',
#      'Chordata',
#      'Reptilia',
#      'Squamata',
#      'Colubridae',
#      'Blythia'],
#     'license': {'id': 'notspecified'},
#     'publication_date': '2017-12-31',
#     'related_identifiers': [{'identifier': 'http://treatment.plazi.org/id/83036772FFCB0A31FF4DFBA8002C86BD',
#       'relation': 'isCitedBy',
#       'scheme': 'url'},
#      {'identifier': '10.11646/zootaxa.4276.4.8',
#       'relation': 'isPartOf',
#       'scheme': 'doi'},
#      {'identifier': 'urn:lsid:plazi.org:pub:7F3A1F0AFFCA0A39FFDAFFB204348645',
#       'relation': 'isPartOf',
#       'scheme': 'lsid'},
#      {'identifier': 'https://zenodo.org/record/808066',
#       'relation': 'isPartOf',
#       'scheme': 'url'},
#      {'identifier': '10.5281/zenodo.808079',
#       'relation': 'isPartOf',
#       'scheme': 'doi'}],
#     'relations': {'version': [{'count': 1,
#        'index': 0,
#        'is_last': True,
#        'last_child': {'pid_type': 'recid', 'pid_value': '808080'},
#        'parent': {'pid_type': 'recid', 'pid_value': '808079'}}]},
#     'resource_type': {'subtype': 'figure', 'title': 'Figure', 'type': 'image'},
#     'title': 'FIGURE 6 in A second species of the genus Blythia Theobald, 1868 (Squamata: Colubridae) from Mizoram, India'},
#    'owners': [1161],
#    'revision': 1,
#    'updated': '2017-06-14T08:24:06.150305+00:00'},
#   {'conceptdoi': '10.5281/zenodo.808069',
#    'conceptrecid': '808069',
#    'created': '2017-06-14T08:23:43.210271+00:00',
#    'doi': '10.5281/zenodo.808070',
#    'id': 808070,
#    'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.808070.svg',
#     'bucket': 'https://zenodo.org/api/files/c8d26aa7-9181-48cc-9b52-d023693d49bc',
#     'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.808069.svg',
#     'conceptdoi': 'https://doi.org/10.5281/zenodo.808069',
#     'doi': 'https://doi.org/10.5281/zenodo.808070',
#     'html': 'https://zenodo.org/record/808070',
#     'latest': 'https://zenodo.org/api/records/808070',
#     'latest_html': 'https://zenodo.org/record/808070',
#     'self': 'https://zenodo.org/api/records/808070'},
#    'metadata': {'access_right': 'open',
#     'access_right_category': 'success',
#     'communities': [{'id': 'biosyslit'}],
#     'creators': [{'name': 'Vogel, Gernot'},
#      {'name': 'Lalremsanga, Hmar Tlawmte'}],
#     'description': 'FIGURE 1. Holotype of Blythia hmuifang sp. nov. (MZMU 714): General view (A) and lateral view of head (B), left side.',
#     'doi': '10.5281/zenodo.808070',
#     'keywords': ['Biodiversity',
#      'Taxonomy',
#      'Animalia',
#      'Chordata',
#      'Reptilia',
#      'Squamata',
#      'Colubridae',
#      'Blythia'],
#     'license': {'id': 'notspecified'},
#     'publication_date': '2017-12-31',
#     'related_identifiers': [{'identifier': 'http://treatment.plazi.org/id/83036772FFCB0A31FF4DFBA8002C86BD',
#       'relation': 'isCitedBy',
#       'scheme': 'url'},
#      {'identifier': '10.11646/zootaxa.4276.4.8',
#       'relation': 'isPartOf',
#       'scheme': 'doi'},
#      {'identifier': 'urn:lsid:plazi.org:pub:7F3A1F0AFFCA0A39FFDAFFB204348645',
#       'relation': 'isPartOf',
#       'scheme': 'lsid'},
#      {'identifier': 'https://zenodo.org/record/808066',
#       'relation': 'isPartOf',
#       'scheme': 'url'},
#      {'identifier': '10.5281/zenodo.808069',
#       'relation': 'isPartOf',
#       'scheme': 'doi'}],
#     'relations': {'version': [{'count': 1,
#        'index': 0,
#        'is_last': True,
#        'last_child': {'pid_type': 'recid', 'pid_value': '808070'},
#        'parent': {'pid_type': 'recid', 'pid_value': '808069'}}]},
#     'resource_type': {'subtype': 'figure', 'title': 'Figure', 'type': 'image'},
#     'title': 'FIGURE 1 in A second species of the genus Blythia Theobald, 1868 (Squamata: Colubridae) from Mizoram, India'},
#    'owners': [1161],
#    'revision': 1,
#    'updated': '2017-06-14T08:23:43.413691+00:00'},
#   {'conceptdoi': '10.5281/zenodo.808077',
#    'conceptrecid': '808077',
#    'created': '2017-06-14T08:24:02.902799+00:00',
#    'doi': '10.5281/zenodo.808078',
#    'id': 808078,
#    'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.808078.svg',
#     'bucket': 'https://zenodo.org/api/files/f83f0aee-c3f9-487d-bfde-bc58158e5231',
#     'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.808077.svg',
#     'conceptdoi': 'https://doi.org/10.5281/zenodo.808077',
#     'doi': 'https://doi.org/10.5281/zenodo.808078',
#     'html': 'https://zenodo.org/record/808078',
#     'latest': 'https://zenodo.org/api/records/808078',
#     'latest_html': 'https://zenodo.org/record/808078',
#     'self': 'https://zenodo.org/api/records/808078'},
#    'metadata': {'access_right': 'open',
#     'access_right_category': 'success',
#     'communities': [{'id': 'biosyslit'}],
#     'creators': [{'name': 'Vogel, Gernot'},
#      {'name': 'Lalremsanga, Hmar Tlawmte'}],
#     'description': 'FIGURE 5. Hemipenes of Blythia reticulata (A) and the holotype of B. hmuifang sp. nov. MZMU 714 (B).',
#     'doi': '10.5281/zenodo.808078',
#     'keywords': ['Biodiversity',
#      'Taxonomy',
#      'Animalia',
#      'Chordata',
#      'Reptilia',
#      'Squamata',
#      'Colubridae',
#      'Blythia'],
#     'license': {'id': 'notspecified'},
#     'publication_date': '2017-12-31',
#     'related_identifiers': [{'identifier': 'http://treatment.plazi.org/id/83036772FFCB0A31FF4DFBA8002C86BD',
#       'relation': 'isCitedBy',
#       'scheme': 'url'},
#      {'identifier': '10.11646/zootaxa.4276.4.8',
#       'relation': 'isPartOf',
#       'scheme': 'doi'},
#      {'identifier': 'urn:lsid:plazi.org:pub:7F3A1F0AFFCA0A39FFDAFFB204348645',
#       'relation': 'isPartOf',
#       'scheme': 'lsid'},
#      {'identifier': 'https://zenodo.org/record/808066',
#       'relation': 'isPartOf',
#       'scheme': 'url'},
#      {'identifier': '10.5281/zenodo.808077',
#       'relation': 'isPartOf',
#       'scheme': 'doi'}],
#     'relations': {'version': [{'count': 1,
#        'index': 0,
#        'is_last': True,
#        'last_child': {'pid_type': 'recid', 'pid_value': '808078'},
#        'parent': {'pid_type': 'recid', 'pid_value': '808077'}}]},
#     'resource_type': {'subtype': 'figure', 'title': 'Figure', 'type': 'image'},
#     'title': 'FIGURE 5 in A second species of the genus Blythia Theobald, 1868 (Squamata: Colubridae) from Mizoram, India'},
#    'owners': [1161],
#    'revision': 1,
#    'updated': '2017-06-14T08:24:03.103662+00:00'}],
#  'total': 391}
